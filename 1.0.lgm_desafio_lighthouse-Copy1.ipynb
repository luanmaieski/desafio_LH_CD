# %%
#!pip install summarytools
#!pip install -U scikit-learn
#!pip install Boruta

# %% [markdown]
# # 0.0. Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import unicodedata
import math
import pickle
from IPython.core.display  import HTML
#from summarytools import dfSummary
from matplotlib import pyplot as plt
from sklearn                 import model_selection as ms
from sklearn                 import preprocessing as pp
from sklearn.linear_model  import LinearRegression, Lasso
from sklearn.ensemble      import RandomForestRegressor
from sklearn.metrics       import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error
from sklearn.model_selection import cross_val_score, KFold
import xgboost as xgb
import lightgbm as lgbm
import catboost as catb

from boruta import BorutaPy
from scipy.stats import expon, randint

import warnings
warnings.filterwarnings( 'ignore' )

# %% [markdown]
# ## 0.1 Helper Functions

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    plt.rcParams['figure.figsize'] = [25, 15]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container {width:90% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    sns.set_theme(style="darkgrid", palette='hls')
    # sns.color_palette("crest", as_cmap=True)
    # sns.color_palette("magma", as_cmap=True)
    # sns.color_palette("flare", as_cmap=True)
    # Increase chart size for better readability
    #sns.set(rc={'figure.figsize':(11,6)})

jupyter_settings()

def mean_percentage_error( y, yhat ):
    return np.mean( ( y - yhat ) / y )

def ml_error( model_name, y, yhat ):
    mae = mean_absolute_error( y, yhat )
    mape = mean_absolute_percentage_error( y, yhat )
    rmse = np.sqrt( mean_squared_error( y, yhat ) )

    return pd.DataFrame( { 'Model Name': [model_name],
                           'MAE': [mae],
                           'MAPE': [mape],
                           'RMSE': [rmse]} )

def cross_validation_regression(model, x_train, y_train, k, verbose=True):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    mae_list = []
    mape_list = []
    rmse_list = []
    i = 1    
    for train_cv, val_cv in kf.split(x_train, y_train):
        if verbose:
            print(f'Fold Number {i}/{k}') 
        else:
            pass

        x_train_fold = x_train.iloc[train_cv]
        y_train_fold = y_train.iloc[train_cv]

        x_val_fold = x_train.iloc[val_cv]
        y_val_fold = y_train.iloc[val_cv]

        # fit model
        model.fit(x_train_fold, y_train_fold)

        # predict
        yhat_model = model.predict(x_val_fold)

        #performance
        m_result = ml_error( model, np.expm1( y_val_fold ), np.expm1( yhat_model ) )
        
        # Calculate regression metrics for the fold
        mae_list.append( m_result[ 'MAE' ] )
        mape_list.append( m_result[ 'MAPE' ] )
        rmse_list.append( m_result[ 'RMSE' ] )
       
        i += 1

    results_dict = {'Model Name': type(model).__name__,
                       'MAE Mean': np.round(np.mean(mae_list), 4),
                       'MAPE Mean': np.round(np.mean(mape_list), 4),
                       'RMSE Mean': np.round(np.mean(rmse_list), 4)}
    return results_dict
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# <style>.container {width:90% !important; }</style>

# %% [markdown]
# ## 0.2 Loading Data

# %%
cars_train_raw = pd.read_csv( 'data/cars_train.csv', encoding='utf-16',  delimiter='\t')

# %% [markdown]
# # 1.0. Data Description

# %%
df1 = cars_train_raw.copy()

# %%
df1.sample(5)
# Out:
#                                             id  num_fotos    marca  modelo                                            versao  ano_de_fabricacao  ano_modelo  hodometro      cambio  num_portas    tipo blindado     cor tipo_vendedor        cidade_vendedor estado_vendedor      anunciante  entrega_delivery  troca  elegivel_revisao  dono_aceita_troca  veiculo_unico_dono  revisoes_concessionaria  ipva_pago  veiculo_licenciado  garantia_de_fabrica  revisoes_dentro_agenda          preco
# 24892  193981998589938963910588892070646640785          8     FIAT    TORO              2.0 16V TURBO DIESEL VOLCANO 4WD AT9               2020        2020    21478.0  Automática           4  Picape        N  Branco            PF              São Paulo  São Paulo (SP)   Pessoa Física             False  False             False                  0                   1                        1          1                   1                    1                       1  158646.357269
# 4921   285754969879088331964116352147170495157          8     FORD  FUSION       2.0 TITANIUM PLUS 16V HÍBRIDO 4P AUTOMÁTICO               2018        2018    24351.0  Automática           4    Sedã        N  Branco            PF               Salvador      Bahia (BA)   Pessoa Física             False  False             False                  1                   0                        0          0                   0                    0                       0  179128.689227
# 29301  152663906798306262615612353272780132734         14  HYUNDAI   HB20S               1.0 COMFORT PLUS 12V FLEX 4P MANUAL               2017        2018    74625.0      Manual           4    Sedã        N  Branco            PJ  São Bernardo do Campo  São Paulo (SP)  Concessionária              True   True             False                  1                   0                        0          0                   0                    0                       0   64417.263775
# 25792  338585825402731907853862017022409055737         16     FORD  RANGER       3.2 LIMITED 4X4 CD 20V DIESEL 4P AUTOMÁTICO               2013        2013    82411.0  Automática           2  Picape        N  Branco            PJ              São Paulo  São Paulo (SP)            Loja              True   True             False                  1                   0                        0          0                   1                    0                       0  169173.436528
# 23074  243988151966591371657438446327329243015         15     MINI  COOPER  2.0 S EXCLUSIVE 16V TURBO GASOLINA 4P AUTOMÁTICO               2012        2015    62752.0  Automática           4  Picape        N   Preto            PJ              São Paulo  São Paulo (SP)            Loja              True  False             False                  1                   0                        0          1                   1                    0                       0  220415.869908

# %% [markdown]
# ## 1.1 Rename Columns

# %%
df1.columns = [unicodedata.normalize('NFKD', col).encode('ASCII', 'ignore').decode('utf-8') for col in df1.columns]

# %% [markdown]
# ## 1.2 Data Dimensions

# %%
print( 'Number of Rows: {}'.format(df1.shape[0]))
print( 'Number of Cols: {}'.format(df1.shape[1]))
# Out:
# Number of Rows: 29584
# Number of Cols: 29

# %% [markdown]
# ## 1.3 Data Types

# %%
df1.dtypes
# Out:
# id                          object
# num_fotos                  float64
# marca                       object
# modelo                      object
# versao                      object
# ano_de_fabricacao            int64
# ano_modelo                 float64
# hodometro                  float64
# cambio                      object
# num_portas                   int64
# tipo                        object
# blindado                    object
# cor                         object
# tipo_vendedor               object
# cidade_vendedor             object
# estado_vendedor             object
# anunciante                  object
# entrega_delivery              bool
# troca                         bool
# elegivel_revisao              bool
# dono_aceita_troca           object
# veiculo_unico_dono          object
# revisoes_concessionaria     object
# ipva_pago                   object
# veiculo_licenciado          object
# garantia_de_fabrica         object
# revisoes_dentro_agenda      object
# veiculo_alienado           float64
# preco                      float64
# dtype: object

# %% [markdown]
# ## 1.4 Check NA

# %%
df1.isna().sum()
# Out:
# id                             0
# num_fotos                    177
# marca                          0
# modelo                         0
# versao                         0
# ano_de_fabricacao              0
# ano_modelo                     0
# hodometro                      0
# cambio                         0
# num_portas                     0
# tipo                           0
# blindado                       0
# cor                            0
# tipo_vendedor                  0
# cidade_vendedor                0
# estado_vendedor                0
# anunciante                     0
# entrega_delivery               0
# troca                          0
# elegivel_revisao               0
# dono_aceita_troca           7662
# veiculo_unico_dono         19161
# revisoes_concessionaria    20412
# ipva_pago                   9925
# veiculo_licenciado         13678
# garantia_de_fabrica        25219
# revisoes_dentro_agenda     23674
# veiculo_alienado           29584
# preco                          0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 1.5 Fillout NA

# %%
# A coluna 'veiculo_alienado' está com todas as linhas vazias então será removida
df1 = df1.drop(['veiculo_alienado'], axis=1)

# Na coluna 'num_fotos' assumo que os dados com valores vazios não tem fotos, substituindo por 0.
df1['num_fotos'] = df1['num_fotos'].apply( lambda x: 0 if math.isnan(x) else x )

# Nas colunas ['dono_aceita_troca', 'veiculo_unico_dono', 'revisoes_concessionaria', 'ipva_pago', 'veiculo_licenciado', 'garantia_de_fabrica', 'revisoes_dentro_agenda'] conisdero que as linhas com valores vazios significa 'Não' e serão substituidas por 0 e as linhas que tem informação significam 'Sim' e serão substituidas por 1.
df1['dono_aceita_troca'] = df1['dono_aceita_troca'].apply( lambda x: 0 if pd.isna(x) else 1 )
df1['veiculo_unico_dono'] = df1['veiculo_unico_dono'].apply( lambda x: 0 if pd.isna(x) else 1 )
df1['revisoes_concessionaria'] = df1['revisoes_concessionaria'].apply( lambda x: 0 if pd.isna(x) else 1 )
df1['ipva_pago'] = df1['ipva_pago'].apply( lambda x: 0 if pd.isna(x) else 1 )
df1['veiculo_licenciado'] = df1['veiculo_licenciado'].apply( lambda x: 0 if pd.isna(x) else 1 )
df1['garantia_de_fabrica'] = df1['garantia_de_fabrica'].apply( lambda x: 0 if pd.isna(x) else 1 )
df1['revisoes_dentro_agenda'] = df1['revisoes_dentro_agenda'].apply( lambda x: 0 if pd.isna(x) else 1 )

# %%
df1.isna().sum()
# Out:
# id                         0
# num_fotos                  0
# marca                      0
# modelo                     0
# versao                     0
# ano_de_fabricacao          0
# ano_modelo                 0
# hodometro                  0
# cambio                     0
# num_portas                 0
# tipo                       0
# blindado                   0
# cor                        0
# tipo_vendedor              0
# cidade_vendedor            0
# estado_vendedor            0
# anunciante                 0
# entrega_delivery           0
# troca                      0
# elegivel_revisao           0
# dono_aceita_troca          0
# veiculo_unico_dono         0
# revisoes_concessionaria    0
# ipva_pago                  0
# veiculo_licenciado         0
# garantia_de_fabrica        0
# revisoes_dentro_agenda     0
# preco                      0
# dtype: int64

# %% [markdown]
# ## 1.6 Change Types

# %%
df1['num_fotos'] = df1['num_fotos'].astype( 'int64' )
df1['ano_modelo'] = df1['ano_modelo'].astype( 'int64' )

# %%
df1.dtypes
# Out:
# id                          object
# num_fotos                    int64
# marca                       object
# modelo                      object
# versao                      object
# ano_de_fabricacao            int64
# ano_modelo                   int64
# hodometro                  float64
# cambio                      object
# num_portas                   int64
# tipo                        object
# blindado                    object
# cor                         object
# tipo_vendedor               object
# cidade_vendedor             object
# estado_vendedor             object
# anunciante                  object
# entrega_delivery              bool
# troca                         bool
# elegivel_revisao              bool
# dono_aceita_troca            int64
# veiculo_unico_dono           int64
# revisoes_concessionaria      int64
# ipva_pago                    int64
# veiculo_licenciado           int64
# garantia_de_fabrica          int64
# revisoes_dentro_agenda       int64
# preco                      float64
# dtype: object

# %% [markdown]
# ## 1.7 Descriptive Statistical

# %%
Média, Moda e mediana passam a ideia de dispersão
Podem mostrar que os dados tem uma assimetria a esquerda, ou que tem uma dispersão simétrica ou ainda que tem uma assimetria a direita

# %% [markdown]
# ### Numerical Attributes

# %%
num_attributes = df1.select_dtypes( include=['int64', 'float64'] )
cat_attributes = df1.select_dtypes( exclude=['int64', 'float64'] )

# %%
cat_attributes.columns
# Out:
# Index(['id', 'marca', 'modelo', 'versao', 'cambio', 'tipo', 'blindado', 'cor',
#        'tipo_vendedor', 'cidade_vendedor', 'estado_vendedor', 'anunciante',
#        'entrega_delivery', 'troca', 'elegivel_revisao'],
#       dtype='object')

# %%
# Central Tendency - mean, median
ct1 = pd.DataFrame( num_attributes.apply( np.mean ) ).T
ct2 = pd.DataFrame( num_attributes.apply( np.median ) ).T

# Dispercion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame( num_attributes.apply( np.std ) ).T
d2 = pd.DataFrame( num_attributes.apply( min ) ).T.astype(int)
d3 = pd.DataFrame( num_attributes.apply( max ) ).T.astype(int)
d4 = pd.DataFrame( num_attributes.apply( lambda x: x.max() - x.min() ) ).T.astype(int)
d5 = pd.DataFrame( num_attributes.apply( lambda x: x.skew() ) ).T
d6 = pd.DataFrame( num_attributes.apply( lambda x: x.kurtosis() ) ).T

#concatenate
m = pd.concat( [d2, d3, d4, ct1, ct2, d1, d5, d6] ).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis'] 
m
# Out:
#                  attributes     min        max      range           mean         median           std      skew   kurtosis
# 0                 num_fotos     0.0       21.0       21.0      10.262067       8.000000      3.566818  0.837134  -0.390327
# 1         ano_de_fabricacao  1985.0     2022.0       37.0    2016.758552    2018.000000      4.062353 -2.493793   9.189095
# 2                ano_modelo  1997.0     2023.0       26.0    2017.808985    2018.000000      2.673885 -0.498640  -0.522504
# 3                 hodometro   100.0   390065.0   389965.0   58430.592077   57434.000000  32561.218977  0.590908   1.194606
# 4                num_portas     2.0        4.0        2.0       3.940677       4.000000      0.338355 -5.544991  28.797600
# 5         dono_aceita_troca     0.0        1.0        1.0       0.741009       1.000000      0.438081 -1.100349  -0.789286
# 6        veiculo_unico_dono     0.0        1.0        1.0       0.352319       0.000000      0.477693  0.618342  -1.617763
# 7   revisoes_concessionaria     0.0        1.0        1.0       0.310032       0.000000      0.462507  0.821511  -1.325209
# 8                 ipva_pago     0.0        1.0        1.0       0.664515       1.000000      0.472160 -0.696895  -1.514440
# 9        veiculo_licenciado     0.0        1.0        1.0       0.537655       1.000000      0.498580 -0.151059  -1.977315
# 10      garantia_de_fabrica     0.0        1.0        1.0       0.147546       0.000000      0.354649  1.987721   1.951165
# 11   revisoes_dentro_agenda     0.0        1.0        1.0       0.199770       0.000000      0.399828  1.501873   0.255640
# 12                    preco  9869.0  1359812.0  1349942.0  133023.879880  114355.796998  81661.492049  2.148999  10.974860

# %%
# Check preco attribute distribution
sns.displot( df1['preco'], kde=False );

# %% [markdown]
# #### Numerical Attributes Analysis
# * `ano_de_fabricacao` e `ano_modelo`: O menor ano de fabricação é 1985 e o menor ano do modelo é 1997. Precisa ser investigado.

# %% [markdown]
# ### Categorical Attributes

# %%
df1.describe(exclude=np.number).T
# Out:
#                   count unique                                      top   freq
# id                29584  29584  300716223898539419613863097469899222392      1
# marca             29584     40                               VOLKSWAGEN   4594
# modelo            29584    457                                  COMPASS   1480
# versao            29584   1916   1.6 16V FLEX ALLURE PACK 4P AUTOMÁTICO   1352
# cambio            29584      7                               Automática  22545
# tipo              29584      7                                     Sedã  16429
# blindado          29584      2                                        N  29336
# cor               29584      7                                   Branco  20949
# tipo_vendedor     29584      2                                       PF  17926
# cidade_vendedor   29584    575                                São Paulo   6158
# estado_vendedor   29584     25                           São Paulo (SP)  16378
# anunciante        29584      4                            Pessoa Física  17999
# entrega_delivery  29584      2                                    False  23601
# troca             29584      2                                    False  24523
# elegivel_revisao  29584      1                                    False  29584

# %%
cat_attributes.columns
# Out:
# Index(['id', 'marca', 'modelo', 'versao', 'cambio', 'tipo', 'blindado', 'cor',
#        'tipo_vendedor', 'cidade_vendedor', 'estado_vendedor', 'anunciante',
#        'entrega_delivery', 'troca', 'elegivel_revisao'],
#       dtype='object')

# %%
plt.subplot(1, 3, 1)
sns.boxplot( x='cambio', y='preco', data=df1)
plt.xticks(rotation=15);

plt.subplot(1, 3, 2)
sns.boxplot( x='tipo', y='preco', data=df1)

plt.subplot(1, 3, 3)
sns.boxplot( x='cor', y='preco', data=df1)
# Out:
# <Axes: xlabel='cor', ylabel='preco'>

# %%
plt.subplot(1, 3, 1)
sns.boxplot( x='blindado', y='preco', data=df1)

plt.subplot(1, 3, 2)
sns.boxplot( x='tipo_vendedor', y='preco', data=df1)

plt.subplot(1, 3, 3)
sns.boxplot( x='anunciante', y='preco', data=df1)
plt.xticks(rotation=20);

# %%
plt.subplot(1, 3, 1)
sns.boxplot( x='entrega_delivery', y='preco', data=df1)
plt.xticks(rotation=15);

plt.subplot(1, 3, 2)
sns.boxplot( x='troca', y='preco', data=df1)

plt.subplot(1, 3, 3)
sns.boxplot( x='elegivel_revisao', y='preco', data=df1)
# Out:
# <Axes: xlabel='elegivel_revisao', ylabel='preco'>

# %%
sns.boxplot( x='marca', y='preco', data=df1)
plt.xticks(rotation=85);

# %%
df1['cor'].value_counts(normalize=True)
# Out:
# Branco      0.708119
# Preto       0.177664
# Prata       0.058849
# Cinza       0.055233
# Dourado     0.000068
# Verde       0.000034
# Vermelho    0.000034
# Name: cor, dtype: float64

# %% [markdown]
# # 2.0. Feature Engineering

# %%
df2 = df1.copy()

# %%
# Na coluna 'blindado' substitui 'N' por 0 e 'S' por 1
df2['blindado'] = df2['blindado'].apply( lambda x: 0 if x=='N' else 1)

# A coluna 'elegivel_revisao' tem todos as linhas como False e por isso será excluida.
df2 = df2.drop(['elegivel_revisao'], axis=1)

# Nas colunas 'entrega_delivery' e 'troca' substitui False por 0 e True por 1
df2['entrega_delivery'] = df2['entrega_delivery'].apply( lambda x: 0 if x==False else 1)
df2['troca'] = df2['troca'].apply( lambda x: 0 if x==False else 1)

# %%
df2.sample(2).T
# Out:
#                                                           3904                                            29506
# id                       61458893289574375404844154849678421814         322169286657598471070171583328549284996
# num_fotos                                                    14                                               8
# marca                                                VOLKSWAGEN                                      LAND ROVER
# modelo                                                   VIRTUS                              RANGE ROVER EVOQUE
# versao                       1.0 200 TSI COMFORTLINE AUTOMÁTICO  2.0 HSE DYNAMIC 4WD 16V GASOLINA 4P AUTOMÁTICO
# ano_de_fabricacao                                          2020                                            2018
# ano_modelo                                                 2021                                            2018
# hodometro                                               17677.0                                         63309.0
# cambio                                               Automática                                      Automática
# num_portas                                                    4                                               4
# tipo                                                       Sedã                                            Sedã
# blindado                                                      0                                               0
# cor                                                      Branco                                          Branco
# tipo_vendedor                                                PJ                                              PF
# cidade_vendedor                                        Salvador                                   Nova Alvorada
# estado_vendedor                                    Paraíba (PB)                          Rio Grande do Sul (RS)
# anunciante                                                 Loja                                   Pessoa Física
# entrega_delivery                                              0                                               0
# troca                                                         0                                               0
# dono_aceita_troca                                             1                                               1
# veiculo_unico_dono                                            0                                               0
# revisoes_concessionaria                                       0                                               0
# ipva_pago                                                     0                                               1
# veiculo_licenciado                                            0                                               0
# garantia_de_fabrica                                           0                                               0
# revisoes_dentro_agenda                                        0                                               0
# preco                                              86985.500772                                   233764.079398

# %% [markdown]
# ## 2.1. Hypothesis

# %% [markdown]
# 1. Hipótese 1: Os modelos mais vendidos também são os que tem menor média de preço
# 2. Hipótese 2: Carros com transmissão automática têm preços mais altos nas Capitais
# 3. Hipótese 3: Carros vendidos por anunciantes profissionais têm preços mais altos do que carros vendidos por pessoa física.

# %% [markdown]
# ### Hipótese 1: Os modelos com mais oferta de carros também são os que tem menor média de preço
# **Hipótese Falsa** Como visto no gráfico abaixo, os preços dos modelos não tem correlação com a quantidade de ofertas.

# %%
df_aux = df2[['modelo', 'preco', 'id']].groupby('modelo').agg({'preco': 'mean', 'id': 'count'}).sort_values('preco', ascending=True).reset_index()
df_aux = df_aux[df_aux['id']>1]

# %%
df_preco = df2[['modelo', 'preco']].groupby('modelo').mean().sort_values('preco', ascending=True ).reset_index()
df_preco
# Out:
#                    modelo          preco
# 0                   PASEO   18528.457166
# 1                  SYMBOL   18763.904063
# 2                  ESCORT   20161.917961
# 3                      ES   21815.216211
# 4                   STILO   23276.853636
# 5                 SANTANA   24146.950045
# 6                     530   25195.990696
# 7                 COURIER   27416.670303
# 8                   SIENA   30905.751642
# 9                   ASTRA   31855.230504
# 10             PT CRUISER   32492.091364
# 11                  AGILE   32696.607470
# 12                  300 M   33252.104074
# 13                 ZAFIRA   34526.350287
# 14                AIRTREK   34617.047423
# 15                    207   34744.946608
# 16                    S40   35778.172434
# 17                   BORA   36679.281485
# 18                FIELDER   38689.396881
# 19                X-TRAIL   38764.143685
# 20                    V70   38797.091171
# 21                    307   38830.309983
# 22           GRAND BLAZER   39254.074719
# 23                FLUENCE   39569.886963
# 24   PICAPE CAÇAMBA LONGA   40163.175829
# 25                 ES 350   40620.260815
# 26                  CORSA   41187.504495
# 27                     C4   41280.450511
# 28                    407   41750.413445
# 29                  B 180   42114.612024
# 30                 MERIVA   42610.542376
# 31                    S80   43221.745371
# 32                  CELTA   44105.729998
# 33                  OMEGA   44769.620093
# 34                  COUPÉ   45502.755496
# 35                 SONATA   45625.152895
# 36                    SX4   45661.951287
# 37                CLASSIC   46351.586047
# 38                C 230 K   46562.146882
# 39               CROSSFOX   46585.490256
# 40                 LIVINA   47218.553035
# 41                   M-11   47762.671073
# 42                 ML 320   47845.922845
# 43                 I30 CW   48235.238755
# 44             FREELANDER   48635.650702
# 45                C 200 K   48996.473710
# 46                  PUNTO   49376.185211
# 47                  AZERA   49447.246272
# 48                CLK 320   49694.291478
# 49                 VECTRA   50079.168003
# 50                  C 240   50126.460610
# 51                   SOUL   50432.124900
# 52                   KWID   50718.489053
# 53                    D20   50963.753367
# 54                     C3   51546.772419
# 55                   MOBI   51647.590292
# 56                  A 190   51657.294145
# 57             NEW BEETLE   51743.451571
# 58          XSARA PICASSO   51832.943042
# 59                  PALIO   51912.958638
# 60               SPACEFOX   52037.251912
# 61                     S6   52077.401865
# 62                 FIESTA   52616.645749
# 63                     UP   53029.542544
# 64                CARAVAN   53066.468445
# 65                 BLAZER   53625.191807
# 66                TRIBECA   53689.652924
# 67                    UNO   53730.187145
# 68           GRAND LIVINA   54793.395760
# 69                   IDEA   55080.600046
# 70                    FOX   55096.983445
# 71                     KA   55145.540847
# 72               S 55 AMG   55272.838078
# 73                 MÉGANE   55409.763943
# 74                  E 430   55645.688051
# 75                  323Ti   56015.261361
# 76               VERACRUZ   56118.828005
# 77                CAPTIVA   56179.721604
# 78                    408   57014.101270
# 79              SILVERADO   57038.723597
# 80               AIRCROSS   57409.779634
# 81                  MARCH   57497.543950
# 82               CHEROKEE   57728.418543
# 83         TOWN & COUNTRY   57835.987016
# 84           GRAND VITARA   58725.300016
# 85                  LINEA   59293.862860
# 86                  BRAVO   59480.806151
# 87               CROSS UP   60044.931718
# 88                   325i   60465.756216
# 89                  FOCUS   60981.463830
# 90                PICANTO   61561.594603
# 91                 COBALT   61625.115965
# 92                  C 280   61858.262498
# 93             C3 PICASSO   62186.776941
# 94                   550i   62270.150013
# 95                  LOGAN   62373.852789
# 96                  F-250   62413.583784
# 97                CADENZA   62449.451765
# 98                    ONE   63012.465690
# 99            DISCOVERY 3   63044.692653
# 100                  CLIO   63492.298808
# 101                   I30   63528.118123
# 102                  316i   63596.704179
# 103                   156   64300.276513
# 104               GLK 300   64774.952933
# 105                 ETIOS   65045.798373
# 106                  HB20   65603.791480
# 107               SANDERO   66081.522258
# 108            PAJERO TR4   66112.695145
# 109              VELOSTER   67216.459804
# 110             C4 LOUNGE   67748.307298
# 111                   308   67779.166857
# 112              E 55 AMG   67987.896494
# 113                LANCER   68131.537686
# 114                  KA +   68726.992355
# 115                MALIBU   69165.622099
# 116                 EQUUS   70135.551562
# 117                DAKOTA   70526.005598
# 118                   147   71270.356541
# 119              FREEMONT   71466.087126
# 120                   208   71619.342713
# 121                 C 350   71668.212884
# 122                  335i   71856.238976
# 123                  ARGO   72416.063799
# 124               JOURNEY   72419.725504
# 125                   T40   72449.838007
# 126                VOYAGE   72498.457389
# 127                F-1000   72792.384420
# 128                  CITY   73384.073264
# 129                DUSTER   73448.650810
# 130               MONTANA   73536.277941
# 131                STRADA   73642.571569
# 132            C4 PICASSO   75041.096707
# 133                   FIT   75148.998093
# 134                   C30   75648.240965
# 135                VIRTUS   75743.877490
# 136                  116i   76150.472742
# 137          QUATTROPORTE   76631.453118
# 138                 KOMBI   77180.232661
# 139               ELANTRA   77656.601425
# 140              ARRIZO 5   79031.684898
# 141               SLK 230   79365.823595
# 142                CARENS   79975.767655
# 143                  L200   80431.959290
# 144                 VERSA   80691.128693
# 145                XTERRA   81033.108208
# 146                PRISMA   81074.020503
# 147                 HB20X   81775.848493
# 148                   CRV   82111.583870
# 149                CERATO   82731.897602
# 150               TRACKER   83647.854214
# 151                SENTRA   83802.220093
# 152                  SPIN   83826.652753
# 153               TIGGO 2   83874.793833
# 154                   RIO   84066.509531
# 155                   JOY   84142.095278
# 156                  ONIX   84272.310265
# 157               SAVEIRO   84575.459750
# 158           ETIOS CROSS   84638.502574
# 159               KORANDO   84982.203734
# 160          DUSTER OROCH   84985.951645
# 161                MOHAVE   85153.629418
# 162                 E 350   85195.238010
# 163                 HB20S   85220.394145
# 164                 300 C   85324.766467
# 165                TUCSON   85409.806597
# 166                  POLO   85610.815189
# 167                   GOL   85818.287588
# 168                  535i   86147.692794
# 169               TRANSIT   86581.946149
# 170                   X60   87095.004432
# 171                  118i   87442.181439
# 172                CAPTUR   87781.517227
# 173               C 180 K   88134.957657
# 174                 CRUZE   88442.162992
# 175           GRAND SIENA   88895.629216
# 176                  130i   89436.618094
# 177                   ASX   89590.366653
# 178                ML 350   89931.808371
# 179              ECOSPORT   90441.388916
# 180                 TIIDA   90527.786808
# 181               ECLIPSE   90620.091435
# 182                  545i   90810.406880
# 183                 DOBLÒ   91112.058063
# 184                FORTWO   91242.896761
# 185                CRONOS   91516.549390
# 186                   500   91522.991863
# 187                 YARIS   91558.943648
# 188                 CRETA   91701.038446
# 189                    S4   91758.932037
# 190                 B 200   92279.508428
# 191                 SONIC   93037.040503
# 192                 BOXER   93141.584091
# 193                 PRIUS   93237.782123
# 194                 E 500   93359.957759
# 195                 KICKS   93763.912110
# 196          FREELANDER 2   94087.254801
# 197           SPACE CROSS   94725.326720
# 198             C4 CACTUS   95322.445876
# 199                   RS3   95640.461123
# 200                ACCORD   95810.913262
# 201                 S 500   95826.770574
# 202                    A1   96358.266053
# 203             CLC 200 K   96393.101516
# 204                   DS5   98088.078779
# 205                  IX35   98588.953884
# 206      C4 GRAND PICASSO   98795.796052
# 207               PARTNER   99624.577419
# 208                  WR-V  100059.115606
# 209              RENEGADE  102434.380396
# 210                KANGOO  102997.943737
# 211            POLO SEDAN  103439.933508
# 212              ARRIZO 6  104394.768450
# 213              TIGGO 3X  105401.242596
# 214               S-CROSS  105617.651969
# 215                VITARA  105776.539229
# 216                   X80  106311.477963
# 217               COROLLA  106391.590724
# 218                 E 320  107418.846833
# 219                JUMPER  107957.405817
# 220                 JIMNY  108416.655827
# 221               T-CROSS  108469.816922
# 222              SANTA FÉ  108490.269563
# 223                    XV  109320.598573
# 224                 CIVIC  109404.647233
# 225                 PULSE  109409.303011
# 226               DURANGO  110651.775241
# 227                FUSION  112354.299364
# 228                  F360  114439.236279
# 229                 JETTA  114853.834541
# 230             ML 63 AMG  116159.208523
# 231                  120i  116234.122045
# 232            COUNTRYMAN  116236.743987
# 233              TIGGO 5x  116379.154786
# 234                    i8  117378.287130
# 235               FIORINO  118059.937533
# 236                  EDGE  118779.936791
# 237                 FUSCA  118782.808881
# 238          L200 OUTDOOR  119891.380017
# 239                    XF  120092.366788
# 240               PACEMAN  120190.048239
# 241                 A 200  121242.629488
# 242               SORENTO  121376.569913
# 243               SLK 200  121542.741808
# 244                CT200H  121997.628424
# 245              SPORTAGE  122042.805927
# 246                   DS4  122070.188685
# 247                    HR  122440.573689
# 248                PASSAT  123751.916453
# 249          PAJERO DAKAR  123800.586219
# 250                  2008  125196.789856
# 251                   RAM  125309.699880
# 252                  TORO  127506.003056
# 253                   V40  127803.098852
# 254                DUCATO  127874.365413
# 255                  HR-V  129978.173879
# 256              ROADSTER  130061.615527
# 257                 NIVUS  130410.768456
# 258               ES 300h  130551.567945
# 259               BOXSTER  131029.812385
# 260             OUTLANDER  131821.069295
# 261               CLA 250  132387.310928
# 262                  GOLF  133032.522798
# 263                   XKR  133510.282221
# 264             SL 63 AMG  133947.832383
# 265                 CAMRY  137703.875710
# 266        GRAND CHEROKEE  138100.917852
# 267                   T60  138263.180118
# 268              WRANGLER  138530.203992
# 269           L200 TRITON  139182.012396
# 270                 BONGO  139840.260353
# 271                    A4  141407.546195
# 272              FORESTER  141619.435733
# 273                    T4  142355.082850
# 274           DISCOVERY 4  142723.084741
# 275                    A3  143699.193840
# 276                    Z3  144046.665256
# 277           L200 SAVANA  144726.278443
# 278                LEGACY  145287.293578
# 279               CLA 200  146096.689359
# 280                  5008  146312.160963
# 281                  528i  147210.068134
# 282        GRAND SANTA FÉ  147551.728638
# 283                    Q3  147676.601620
# 284               TIGGO 7  148056.060245
# 285               COMPASS  148666.994275
# 286                   S10  149744.219261
# 287                    S3  150172.072819
# 288                   RCZ  150396.280598
# 289                 C 180  150928.600342
# 290                 DAILY  151197.557227
# 291                  220i  151845.985159
# 292               GLA 200  153674.701413
# 293              FRONTIER  154362.621063
# 294                MASTER  154453.374548
# 295             GL 63 AMG  154478.558262
# 296               EQUINOX  154918.363301
# 297               CLA 180  156027.162976
# 298                PAJERO  156188.784873
# 299               GLK 220  156963.098196
# 300                  225i  157738.759502
# 301                EXPERT  157806.259092
# 302               S 500 L  157847.798270
# 303                 C 200  158396.263052
# 304                COOPER  158602.410912
# 305                   ZOE  159404.350631
# 306       OUTLANDER SPORT  159506.293322
# 307         ECLIPSE CROSS  161932.753903
# 308               TOUAREG  163740.674605
# 309              E 63 AMG  164605.660971
# 310            SLK 55 AMG  164922.902158
# 311                  3008  165127.532550
# 312                    A6  166399.834522
# 313          PAJERO SPORT  167295.143585
# 314               GLA 250  168239.296453
# 315                    Q7  169253.265033
# 316             TERRITORY  169604.343334
# 317                  RAV4  169638.366962
# 318              SPRINTER  169806.795588
# 319               NX 200T  171426.585994
# 320                 JUMPY  171723.914921
# 321                 A 250  171835.056155
# 322                    M6  172387.757322
# 323                  328i  173119.522063
# 324                   V60  173443.894207
# 325                  125i  174566.786858
# 326                F-TYPE  175701.551901
# 327                   S60  176585.606363
# 328            GLA 45 AMG  177791.100378
# 329           TRAILBLAZER  179296.799991
# 330                AMAROK  180974.399682
# 331                  320i  181137.496779
# 332                NX 300  183512.185104
# 333    RANGE ROVER EVOQUE  183757.198131
# 334                TIGUAN  185515.596875
# 335                  TAOS  186305.821580
# 336               TIGGO 8  187547.789476
# 337                 C 250  189010.144800
# 338                CAYMAN  189922.674906
# 339                RANGER  193597.367180
# 340         COROLLA CROSS  194070.239806
# 341                  218i  194271.123112
# 342                 C 450  195754.307366
# 343                    Q5  197254.056114
# 344             HILUX SW4  197323.359944
# 345               SLK 250  197943.577641
# 346                  XC60  198541.343532
# 347         RX350 F-SPORT  199210.795771
# 348       DISCOVERY SPORT  201356.248605
# 349        PASSAT VARIANT  204434.432842
# 350                    X1  205071.909707
# 351                    A5  205839.216046
# 352                  750i  206004.946315
# 353                  LEAF  208363.629828
# 354                 E 250  208890.963851
# 355              G 63 AMG  209159.510901
# 356               UX 250h  209498.448414
# 357               IMPREZA  211394.044793
# 358                    XE  212567.369719
# 359               CLS 400  212573.943490
# 360                  428i  214096.732275
# 361             AMG GT 63  214101.337005
# 362                    X3  216684.010565
# 363                    i3  218551.621128
# 364                  430i  221345.846602
# 365                    X4  223383.148781
# 366                  XC40  224453.590839
# 367                M 135i  224559.767049
# 368               NX 300h  225197.213166
# 369                 HILUX  225263.039886
# 370                    X2  228829.185302
# 371                M 235i  229088.095705
# 372              A 45 AMG  232625.657471
# 373               CLS 450  234840.112578
# 374               CLS 350  235298.902574
# 375                    TT  237346.331158
# 376                 C 300  238102.310527
# 377                    X5  238706.262371
# 378                GHIBLI  239401.213125
# 379                   TX4  242369.157869
# 380           PAJERO FULL  243996.468238
# 381               RX 450h  244556.403282
# 382     RANGE ROVER SPORT  244606.832819
# 383              CARNIVAL  248540.951998
# 384                E-PACE  250442.382303
# 385                  540i  251838.127633
# 386                CAMARO  254211.444540
# 387             COMMANDER  256169.101741
# 388                  XC90  257035.779863
# 389                   S90  258147.985036
# 390                  BOLT  258347.358351
# 391                F-PACE  259735.031733
# 392          BRONCO SPORT  260766.274503
# 393     RANGE ROVER VOGUE  260895.406844
# 394               SLC 300  262253.579370
# 395                 E 300  262852.532200
# 396                E-TRON  264336.236025
# 397                    X6  264685.300995
# 398                M 340i  265269.723036
# 399                  420i  265762.966610
# 400                  530e  266649.349182
# 401                  530i  267133.109128
# 402                  330e  271045.237689
# 403                   TTS  274677.634877
# 404               GLE 400  274686.853889
# 405              C 43 AMG  275012.306904
# 406              GLC 220d  277836.411804
# 407               GLB 200  278209.919929
# 408                I-PACE  279296.721190
# 409               GLC 250  282352.272582
# 410               CAYENNE  282676.077851
# 411            GLC 43 AMG  286656.703236
# 412            CLA 45 AMG  287133.931369
# 413                  330i  289388.443986
# 414                 745Le  292493.757273
# 415                M 240i  294860.859186
# 416            GLC 63 AMG  295433.622877
# 417                 RS Q3  295652.479492
# 418              A 35 AMG  296418.471862
# 419                   SQ5  296490.351353
# 420                 MACAN  296974.251606
# 421            CLS 53 AMG  304144.111563
# 422              GLE 400d  304471.086119
# 423                  640i  305085.615849
# 424                M 850i  307981.132945
# 425               GLC 300  311692.049495
# 426               GLS 350  313002.011340
# 427               GLE 350  316697.272055
# 428                    M3  317618.260727
# 429              C 63 AMG  319834.444717
# 430                  2500  321207.866029
# 431                AMG GT  321223.756514
# 432                  1500  321229.583395
# 433                    M4  322304.386229
# 434              PANAMERA  326511.123970
# 435               MUSTANG  327147.910284
# 436                 TT RS  329884.786395
# 437                TAYCAN  331393.341402
# 438                    Z4  331676.557101
# 439              DEFENDER  333284.157976
# 440                   RS5  340085.581081
# 441                    A7  359493.704148
# 442                   RS4  361992.499427
# 443             DISCOVERY  363982.656819
# 444                    M5  366901.670854
# 445     RANGE ROVER VELAR  367811.200802
# 446            CLA 35 AMG  376627.198834
# 447            GLE 63 AMG  377230.877960
# 448            GLE 43 AMG  380429.663541
# 449                    M2  385137.997116
# 450                    X7  396520.548258
# 451                   911  411129.303592
# 452                    Q8  413596.682977
# 453                   RS6  413859.960072
# 454                   718  434673.481914
# 455                   RS7  451858.067565
# 456                 S 560  515243.247832

# %%
df_oferta = df2[['modelo', 'id']].groupby('modelo').count().sort_values('id', ascending=False ).reset_index()
df_oferta
# Out:
#                    modelo    id
# 0                 COMPASS  1480
# 1                    2008  1431
# 2                      Q3   914
# 3                    TORO   902
# 4                 COROLLA   867
# 5                    ONIX   855
# 6                    320i   822
# 7                  AMAROK   725
# 8                    GOLF   697
# 9                   HILUX   648
# 10                  CIVIC   625
# 11                  CRUZE   607
# 12                   POLO   571
# 13                  JETTA   512
# 14                  HB20S   460
# 15               RENEGADE   433
# 16                 STRADA   415
# 17                   HB20   386
# 18              HILUX SW4   364
# 19                MONTANA   360
# 20                 VIRTUS   359
# 21                T-CROSS   339
# 22                   IX35   333
# 23                    FIT   330
# 24                     A3   310
# 25                 RANGER   307
# 26                  CRETA   304
# 27               ECOSPORT   302
# 28                   HR-V   300
# 29                 TIGUAN   294
# 30        DISCOVERY SPORT   272
# 31                    GOL   268
# 32               SPORTAGE   262
# 33                    S10   251
# 34                  C 180   216
# 35                   SPIN   210
# 36                    ASX   207
# 37                 TUCSON   205
# 38                     X1   203
# 39     RANGE ROVER EVOQUE   190
# 40            PAJERO FULL   189
# 41              OUTLANDER   178
# 42                    CRV   176
# 43                     T4   166
# 44                   2500   164
# 45                    FOX   161
# 46                 PRISMA   157
# 47                  A 200   155
# 48                TRACKER   148
# 49                 CAPTUR   144
# 50                   XC60   142
# 51                SAVEIRO   142
# 52                  YARIS   141
# 53                  MACAN   139
# 54                  KICKS   131
# 55                  VERSA   126
# 56                   ARGO   124
# 57      RANGE ROVER SPORT   123
# 58               SANTA FÉ   117
# 59                     UP   111
# 60                     A4   105
# 61                    JOY   105
# 62                 COOPER   105
# 63                 PASSAT   102
# 64                   3008    95
# 65                   CITY    95
# 66               FRONTIER    95
# 67                SANDERO    94
# 68                 DUSTER    90
# 69                CAYENNE    89
# 70                  C 250    86
# 71                    208    85
# 72                     KA    83
# 73                EQUINOX    83
# 74                  FUSCA    83
# 75                  DOBLÒ    82
# 76                     X5    81
# 77                     Q7    80
# 78                GLA 200    78
# 79                   328i    77
# 80                 VOYAGE    76
# 81            TRAILBLAZER    73
# 82                  FOCUS    70
# 83                SORENTO    69
# 84                 FUSION    69
# 85                    UNO    67
# 86                  ETIOS    66
# 87                   KA +    66
# 88                     M3    65
# 89           DUSTER OROCH    64
# 90                  LOGAN    63
# 91                     A5    61
# 92            L200 TRITON    61
# 93              DISCOVERY    60
# 94            GRAND SIENA    59
# 95                     X4    58
# 96                    I30    58
# 97                 LANCER    58
# 98                   WR-V    57
# 99          ECLIPSE CROSS    53
# 100                  RAV4    51
# 101                    TT    51
# 102               GLA 250    51
# 103                FIESTA    50
# 104                    C3    49
# 105                F-PACE    48
# 106               ELANTRA    47
# 107                MASTER    47
# 108                 PALIO    46
# 109                  120i    46
# 110     RANGE ROVER VELAR    45
# 111                    XE    45
# 112                 AZERA    44
# 113                    Q5    44
# 114               GLC 250    44
# 115               MUSTANG    44
# 116            PAJERO TR4    42
# 117                    X6    42
# 118              SPRINTER    40
# 119              TIGGO 5x    39
# 120        GRAND CHEROKEE    38
# 121             C4 LOUNGE    37
# 122                  LEAF    37
# 123                CRONOS    37
# 124                 NIVUS    36
# 125                  530i    36
# 126              PANAMERA    36
# 127              C 63 AMG    36
# 128                   718    34
# 129                 B 200    34
# 130                  XC90    34
# 131                  528i    34
# 132                    X3    33
# 133              CROSSFOX    33
# 134                  MOBI    33
# 135              AIRCROSS    32
# 136                  XC40    32
# 137               FIORINO    29
# 138                 PRIUS    29
# 139             TERRITORY    27
# 140                CAMARO    27
# 141                   V60    27
# 142              C 43 AMG    27
# 143              FREEMONT    26
# 144                E-PACE    26
# 145                  540i    26
# 146                    A6    26
# 147                ZAFIRA    26
# 148                 A 250    26
# 149              ARRIZO 6    25
# 150               JOURNEY    25
# 151               CLASSIC    25
# 152                    A1    25
# 153                   911    25
# 154               TIGGO 7    25
# 155               TIGGO 2    24
# 156                DUCATO    24
# 157               CLA 200    24
# 158                  430i    24
# 159                  330i    23
# 160               TIGGO 8    22
# 161                 HB20X    22
# 162              CARNIVAL    22
# 163                 MARCH    21
# 164          PAJERO SPORT    21
# 165                 PUNTO    21
# 166              VELOSTER    21
# 167                 KOMBI    21
# 168              WRANGLER    21
# 169                M 135i    20
# 170                    M6    20
# 171                   S60    20
# 172                    XF    20
# 173               NX 300h    20
# 174            COUNTRYMAN    19
# 175                   V40    19
# 176                  KWID    19
# 177                TAYCAN    19
# 178                    HR    18
# 179                    Z4    18
# 180                 C 200    17
# 181                 JUMPY    17
# 182                   207    17
# 183              SPACEFOX    17
# 184                 ASTRA    17
# 185                  EDGE    17
# 186               CAPTIVA    16
# 187                  IDEA    16
# 188        TOWN & COUNTRY    16
# 189                    S3    16
# 190                CERATO    16
# 191                 RS Q3    16
# 192                COBALT    16
# 193       OUTLANDER SPORT    15
# 194              CHEROKEE    15
# 195           DISCOVERY 4    15
# 196                 EQUUS    15
# 197          FREELANDER 2    15
# 198                    C4    15
# 199     RANGE ROVER VOGUE    14
# 200               IMPREZA    14
# 201            GLC 43 AMG    14
# 202               KORANDO    14
# 203                    X2    13
# 204                    M2    13
# 205          PAJERO DAKAR    13
# 206            CLA 45 AMG    13
# 207               NX 200T    13
# 208             COMMANDER    13
# 209           DISCOVERY 3    13
# 210            NEW BEETLE    12
# 211               SLK 200    12
# 212                M 235i    12
# 213                  535i    12
# 214               GLB 200    12
# 215                NX 300    12
# 216                   307    12
# 217                 JIMNY    12
# 218                FORTWO    12
# 219                   RS6    12
# 220               S-CROSS    12
# 221                   500    11
# 222                 TT RS    11
# 223              DEFENDER    11
# 224                   TX4    11
# 225                 C 300    11
# 226                  130i    11
# 227               TRIBECA    11
# 228                SENTRA    11
# 229               CLS 350    11
# 230              ARRIZO 5    10
# 231                DAKOTA    10
# 232          BRONCO SPORT    10
# 233                  428i    10
# 234              A 45 AMG    10
# 235                    i3    10
# 236               CLA 250    10
# 237                  220i    10
# 238              E 63 AMG    10
# 239               GLC 300     9
# 240                 300 C     9
# 241            C3 PICASSO     9
# 242               C 200 K     9
# 243                LIVINA     9
# 244                CT200H     9
# 245               PICANTO     9
# 246                   308     9
# 247                EXPERT     9
# 248                   DS5     8
# 249                  325i     8
# 250                 C 280     8
# 251                PAJERO     8
# 252             C4 CACTUS     8
# 253                  SOUL     8
# 254              TIGGO 3X     8
# 255               SLK 250     8
# 256                 CELTA     8
# 257                 BONGO     8
# 258               UX 250h     8
# 259                 E 250     8
# 260         RX350 F-SPORT     8
# 261                   S90     8
# 262         COROLLA CROSS     8
# 263               TOUAREG     8
# 264              CROSS UP     8
# 265               SLC 300     7
# 266      C4 GRAND PICASSO     7
# 267               GLS 350     7
# 268                   ONE     7
# 269              A 35 AMG     7
# 270               GLK 220     7
# 271              FORESTER     7
# 272            C4 PICASSO     7
# 273          GRAND VITARA     7
# 274                F-TYPE     7
# 275          L200 OUTDOOR     7
# 276                 PULSE     6
# 277                MERIVA     6
# 278                 S 560     6
# 279             ML 63 AMG     6
# 280                  TAOS     6
# 281                GHIBLI     6
# 282                 C 450     6
# 283                 B 180     6
# 284                VITARA     6
# 285                 F-250     6
# 286               CLK 320     6
# 287                 BRAVO     6
# 288                VECTRA     6
# 289               CLA 180     5
# 290                   SQ5     5
# 291                   TTS     5
# 292               PACEMAN     5
# 293          GRAND LIVINA     5
# 294                  330e     5
# 295                    Q8     5
# 296                    XV     5
# 297               CADENZA     5
# 298                  550i     5
# 299                   147     5
# 300                KANGOO     5
# 301                   X60     5
# 302                AMG GT     5
# 303        PASSAT VARIANT     5
# 304              VERACRUZ     5
# 305                 SIENA     5
# 306                 LINEA     5
# 307                  218i     5
# 308               CLS 400     5
# 309                  335i     4
# 310                    M5     4
# 311                   RIO     4
# 312           SPACE CROSS     4
# 313               TRANSIT     4
# 314                 E 300     4
# 315                 S 500     4
# 316             CLC 200 K     4
# 317                BLAZER     4
# 318                CAYMAN     4
# 319                   156     4
# 320        GRAND SANTA FÉ     4
# 321           L200 SAVANA     4
# 322                  5008     4
# 323                   SX4     4
# 324                MOHAVE     4
# 325                ML 350     4
# 326                  1500     4
# 327              GLE 400d     4
# 328                  125i     4
# 329               PARTNER     4
# 330                LEGACY     4
# 331                M 240i     4
# 332             SILVERADO     3
# 333                  225i     3
# 334              E 55 AMG     3
# 335                 CORSA     3
# 336                 COUPÉ     3
# 337                  BOLT     3
# 338                  CLIO     3
# 339                   DS4     3
# 340               S 500 L     3
# 341                MALIBU     3
# 342                 E 320     3
# 343                 OMEGA     3
# 344               BOXSTER     3
# 345                F-1000     3
# 346               GLE 400     3
# 347                   408     3
# 348                E-TRON     3
# 349               ECLIPSE     3
# 350                 BOXER     3
# 351                M 340i     3
# 352            GLA 45 AMG     3
# 353                ACCORD     3
# 354            PT CRUISER     3
# 355                  316i     3
# 356               GLE 350     3
# 357                  750i     3
# 358                   ZOE     3
# 359                 C 350     3
# 360               FIELDER     3
# 361                SYMBOL     2
# 362                SONATA     2
# 363            CLA 35 AMG     2
# 364               C 230 K     2
# 365                   T40     2
# 366                   X80     2
# 367               ES 300h     2
# 368               CLS 450     2
# 369                   407     2
# 370                  L200     2
# 371                MÉGANE     2
# 372                   V70     2
# 373                I30 CW     2
# 374          GRAND BLAZER     2
# 375                  118i     2
# 376               GLK 300     2
# 377            GLE 63 AMG     2
# 378            GLE 43 AMG     2
# 379            POLO SEDAN     2
# 380            FREELANDER     2
# 381               FLUENCE     2
# 382                   RS3     2
# 383                   RS4     2
# 384                 E 430     2
# 385             AMG GT 63     2
# 386                 DAILY     2
# 387               C 180 K     2
# 388                 TIIDA     1
# 389                    X7     1
# 390                   XKR     1
# 391         XSARA PICASSO     1
# 392               X-TRAIL     1
# 393                XTERRA     1
# 394                    Z3     1
# 395                  116i     1
# 396                   T60     1
# 397                  F360     1
# 398                ESCORT     1
# 399                ES 350     1
# 400                    ES     1
# 401                 E 500     1
# 402                 E 350     1
# 403               DURANGO     1
# 404                   D20     1
# 405               COURIER     1
# 406            CLS 53 AMG     1
# 407                CARENS     1
# 408               CARAVAN     1
# 409                 CAMRY     1
# 410                   C30     1
# 411                 C 240     1
# 412                  BORA     1
# 413               AIRTREK     1
# 414                 AGILE     1
# 415                    A7     1
# 416                 A 190     1
# 417                 745Le     1
# 418                  640i     1
# 419                  545i     1
# 420                  530e     1
# 421                   530     1
# 422                  420i     1
# 423                 323Ti     1
# 424                 300 M     1
# 425           ETIOS CROSS     1
# 426              G 63 AMG     1
# 427                 STILO     1
# 428             GL 63 AMG     1
# 429                 SONIC     1
# 430            SLK 55 AMG     1
# 431               SLK 230     1
# 432             SL 63 AMG     1
# 433               SANTANA     1
# 434                   S80     1
# 435                    S6     1
# 436                   S40     1
# 437                    S4     1
# 438              S 55 AMG     1
# 439               RX 450h     1
# 440                   RS7     1
# 441                   RS5     1
# 442              ROADSTER     1
# 443                   RCZ     1
# 444                   RAM     1
# 445          QUATTROPORTE     1
# 446  PICAPE CAÇAMBA LONGA     1
# 447                 PASEO     1
# 448                ML 320     1
# 449                    M4     1
# 450                  M-11     1
# 451                M 850i     1
# 452                JUMPER     1
# 453                I-PACE     1
# 454            GLC 63 AMG     1
# 455              GLC 220d     1
# 456                    i8     1

# %%
# Cria o gráfico com duas escalas y
fig, ax1 = plt.subplots(figsize=(15, 6))
ax2 = ax1.twinx()

# Preço médio (eixo y esquerdo)
ax1.bar(df_preco['modelo'], df_preco['preco'], color='b', alpha=0.7)
ax1.set_ylabel('Preço médio', color='b')

# Quantidade de 'id' (eixo y direito)
ax2.bar(df_oferta['modelo'], df_oferta['id'], color='r', alpha=0.7)
ax2.set_ylabel('Quantidade de id', color='r')

ax1.set_xticklabels(df_preco['modelo'], rotation=90, ha='right')
ax2.set_xticklabels(df_oferta['modelo'], rotation=90, ha='left')
plt.title('Preço médio e quantidade de id por modelo')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Hipótese 2: Carros com transmissão automática têm preços mais altos nas Capitais

# %%
df_cambio_auto = df2.loc[(df2['cambio'] == 'Automática'), :]

# %%
capitais_brasil = ["Rio Branco","Maceió","Macapá","Manaus","Salvador","Fortaleza","Brasília","Vitória","Goiânia","São Luís","Cuiabá","Campo Grande","Belo Horizonte","Belém","João Pessoa","Curitiba","Recife","Teresina","Rio de Janeiro","Natal","Porto Alegre","Porto Velho","Boa Vista","Florianópolis","São Paulo","Aracaju","Palmas"]

df_capitais = df_cambio_auto[df_cambio_auto['cidade_vendedor'].isin(capitais_brasil)]
df_nao_capitais = df_cambio_auto[~df_cambio_auto['cidade_vendedor'].isin(capitais_brasil)]

print('Média de preço de carros com transmissão automática em Capitais {:.2f}'.format(df_capitais.preco.mean()))
print('Média de preço de carros com transmissão automática em outras cidades {:.2f}'.format(df_nao_capitais.preco.mean()))
# Out:
# Média de preço de carros com transmissão automática em Capitais 145118.27
# Média de preço de carros com transmissão automática em outras cidades 147782.63

# %%
df_capitais[['cidade_vendedor', 'preco']].groupby('cidade_vendedor').mean()
# Out:
#                          preco
# cidade_vendedor
# Aracaju          215697.053567
# Belo Horizonte   137079.736961
# Belém            128820.404613
# Boa Vista         62817.814706
# Brasília         140097.788329
# Campo Grande     167821.103785
# Cuiabá           164332.067337
# Curitiba         137575.220390
# Florianópolis    148864.303650
# Fortaleza        100603.068063
# Goiânia          164835.960190
# João Pessoa      107630.469288
# Maceió           131585.263427
# Manaus            94708.810493
# Natal            120471.227446
# Palmas           131082.667065
# Porto Alegre     125061.307903
# Porto Velho      128821.227987
# Recife           117904.127041
# Rio Branco       105114.702550
# Rio de Janeiro   132613.797128
# Salvador         121834.737019
# São Luís         122483.494186
# São Paulo        127007.400754
# Teresina         169178.711038
# Vitória          141352.525079

# %% [markdown]
# ### Hipótese 3: Carros vendidos por anunciantes profissionais têm preços mais altos do que carros vendidos por pessoa física.
# **Falso** A média de preço de venda dos carros anunciados por pessoa física é 12,04% maior do que a média de venda dos anunciantes profissionais.

# %%
df_anun_pro = df2.loc[(df2['anunciante'] == 'Loja') | (df2['anunciante'] == 'Concessionária'), :]
df_anun_pf = df2.loc[df2['anunciante'] == 'Pessoa Física', :]

print('Média de preço de carros vendidos por Loja e Concessionária: {:.2f}'.format(df_anun_pro.preco.mean()))
print('Média de preço de carros vendidos por Pessoa Física: {:.2f}'.format(df_anun_pf.preco.mean()))
# Out:
# Média de preço de carros vendidos por Loja e Concessionária: 123949.03
# Média de preço de carros vendidos por Pessoa Física: 138874.96

# %% [markdown]
# ### a. Qual o melhor estado cadastrado na base de dados para se vender um carro de marca popular e por quê?

# %%
df2.marca.unique()
# Out:
# array(['NISSAN', 'JEEP', 'KIA', 'VOLKSWAGEN', 'SSANGYONG', 'HYUNDAI',
#        'HONDA', 'TOYOTA', 'MITSUBISHI', 'AUDI', 'CITROËN', 'BMW',
#        'CHEVROLET', 'PORSCHE', 'FORD', 'MERCEDES-BENZ', 'TROLLER',
#        'VOLVO', 'LEXUS', 'PEUGEOT', 'RENAULT', 'FIAT', 'MINI',
#        'LAND ROVER', 'CHERY', 'RAM', 'JAGUAR', 'SUZUKI', 'MASERATI',
#        'CHRYSLER', 'DODGE', 'ALFA ROMEO', 'SMART', 'SUBARU', 'LIFAN',
#        'EFFA', 'IVECO', 'JAC', 'FERRARI', 'BRM'], dtype=object)

# %%
# definir quais são as marcas populares
df2[['marca', 'preco', 'id']].groupby([ 'marca']).agg({'id': 'count', 'preco': 'mean'}).reset_index().sort_values( 'id', ascending=False )
# Out:
#             marca    id          preco
# 38     VOLKSWAGEN  4594  117940.087380
# 5       CHEVROLET  3020   93187.683964
# 36         TOYOTA  2180  156195.160143
# 14        HYUNDAI  2043   84419.639625
# 18           JEEP  2000  138367.166001
# 11           FIAT  1918   99711.164582
# 2             BMW  1784  200501.186503
# 1            AUDI  1698  159977.750342
# 28        PEUGEOT  1675  122797.835086
# 13          HONDA  1586  100620.715073
# 24  MERCEDES-BENZ  1125  176870.776900
# 12           FORD  1060  127453.062261
# 26     MITSUBISHI   862  142199.287880
# 20     LAND ROVER   760  223615.184184
# 31        RENAULT   538   82649.368865
# 27         NISSAN   438  109275.319281
# 19            KIA   408  123252.810780
# 29        PORSCHE   349  317187.326542
# 39          VOLVO   287  198797.855659
# 7         CITROËN   194   73494.483671
# 37        TROLLER   177  148570.646834
# 30            RAM   168  321208.383109
# 4           CHERY   153  121716.542250
# 17         JAGUAR   148  220195.137182
# 25           MINI   137  146232.484657
# 21          LEXUS    75  184938.449707
# 34         SUBARU    41  138272.951868
# 35         SUZUKI    41   92604.776444
# 8           DODGE    37   74370.666721
# 6        CHRYSLER    30   62569.784569
# 33      SSANGYONG    14   84982.203734
# 32          SMART    12   91242.896761
# 0      ALFA ROMEO     9   68172.543195
# 22          LIFAN     8   84161.746098
# 23       MASERATI     7  216148.390267
# 16            JAC     3   94387.618711
# 15          IVECO     2  151197.557227
# 10        FERRARI     1  114439.236279
# 9            EFFA     1   40163.175829
# 3             BRM     1   47762.671073

# %%
# Marcas populares definidas
marca_popular = ['VOLKSWAGEN', 'CHEVROLET', 'HYUNDAI', 'FIAT']

# %%
# Filtrando o dataset apenas com as marcas populares
df_marca_popular = df2.loc[df2['marca'].isin(marca_popular), :]

# %%
df_marca_popular.shape
# Out:
# (11575, 28)

# %%
# transformações de colunas para fazer a tabela
df_marca_popular['tipo_vendedor'] = df_marca_popular['tipo_vendedor'].str.strip()
tipovendedor = {'PJ': 0 , 'PF': 1}
df_marca_popular['tipo_vendedor'] = df_marca_popular['tipo_vendedor'].map( tipovendedor )

# %%
aux = df_marca_popular[['dono_aceita_troca', 'estado_vendedor', 'anunciante', 'id', 'tipo_vendedor', 'preco']].groupby('estado_vendedor').agg({'id':'count', 'dono_aceita_troca': 'sum', 'tipo_vendedor': 'sum', 'preco': 'mean'}).reset_index().sort_values('id', ascending=False)
aux['perc_troca'] = round((aux.dono_aceita_troca / aux.id *100), 2)
aux['perc_vendedor_pf'] = round((aux.tipo_vendedor / aux.id *100), 2)
aux.head(10)
# Out:
#            estado_vendedor    id  dono_aceita_troca  tipo_vendedor          preco  perc_troca  perc_vendedor_pf
# 23          São Paulo (SP)  6522               4819           3492   99774.456317       73.89             53.54
# 18     Rio de Janeiro (RJ)  1003                736            506  105093.384962       73.38             50.45
# 11             Paraná (PR)   902                659            455  112368.709135       73.06             50.44
# 21     Santa Catarina (SC)   847                661            399   99840.590068       78.04             47.11
# 10       Minas Gerais (MG)   663                457            369  108069.037520       68.93             55.66
# 17  Rio Grande do Sul (RS)   566                339            375  110617.199854       59.89             66.25
# 6               Goiás (GO)   303                205            192  119892.820649       67.66             63.37
# 3               Bahia (BA)   255                237            124   99310.886251       92.94             48.63
# 14         Pernambuco (PE)   132                123             28   92075.212611       93.18             21.21
# 12            Paraíba (PB)    80                 80              5   87533.702297      100.00              6.25

# %% [markdown]
# #### Para responder essa pergunta considerei 4 fatores:
# * `id`: Calculando a soma de veiculos por estado, que seria a oferta por estado, eu assumi que quanto maior a oferta, mais favorável economicamente a região é para fazer negócio.
# * `preco`: Quanto maior a média de preço de um estado, maoir será meu lucro caso eu consiga vender.
# * `tipo_vendedor`: Quanto maoir a proporção de vendedores PF em comparação com PJ, menos concorrência de outras lojas eu terei
# * `dono_aceita_troca`: Se o vendedor aceita troca, tenho mais alternativas para fazer algum negócio com ele.
#
# O melhor Estado para se vender um carro de marca popular é **Goiás(GO)**. Analisando a tabela acima, conclui: Entre os 10 Estados com mais ofertas, ele é o que tem maior média de preço e é o segundo maior em proporção de vendedores PF, apesar de estar a baixo da média em relação ao vendedor aceitar troca.

# %% [markdown]
# ### b. Qual o melhor estado para se comprar uma picape com transmissão automática e por quê?

# %%
df_picape_auto = df2.loc[(df2['cambio'] == 'Automática') & (df2['tipo'] == 'Picape'), :]

# %%
df_picape_auto.shape
# Out:
# (3300, 28)

# %%
df_picape_auto[['estado_vendedor', 'preco', 'id']].groupby('estado_vendedor').agg({'preco': 'mean', 'id': 'count'}).sort_values('preco', ascending=True)
# Out:
#                                   preco    id
# estado_vendedor
# Paraíba (PB)               93157.035264     4
# Mato Grosso do Sul (MS)   144700.247621     5
# Acre (AC)                 145256.693656     6
# Rio Grande do Norte (RN)  179961.694768     1
# Rio de Janeiro (RJ)       181660.344685   318
# Santa Catarina (SC)       185848.618546   283
# Tocantins (TO)            187717.127524     3
# São Paulo (SP)            188427.484638  1712
# Pernambuco (PE)           192566.764505    14
# Rio Grande do Sul (RS)    195251.763134   198
# Minas Gerais (MG)         195702.914796   211
# Paraná (PR)               198384.949644   348
# Bahia (BA)                206364.799217    68
# Goiás (GO)                208153.658437   102
# Piauí (PI)                208181.077756     4
# Mato Grosso (MT)          214102.315642     6
# Alagoas (AL)              218671.542780    12
# Sergipe (SE)              298195.309673     5

# %%
df_aux = df_picape_auto.loc[df_picape_auto['garantia_de_fabrica'] == 1 , :]
df_aux[['estado_vendedor', 'preco', 'id']].groupby('estado_vendedor').agg({'preco': 'mean', 'id': 'count'}).sort_values('preco', ascending=True)
# Out:
#                                   preco   id
# estado_vendedor
# Rio Grande do Norte (RN)  179961.694768    1
# Mato Grosso (MT)          197657.066561    2
# Minas Gerais (MG)         210890.490416   36
# Pernambuco (PE)           222166.668612    2
# São Paulo (SP)            222523.322315  282
# Rio Grande do Sul (RS)    224316.599327   39
# Rio de Janeiro (RJ)       227941.875261   57
# Acre (AC)                 228022.077115    1
# Alagoas (AL)              229622.921633   10
# Paraná (PR)               230804.366816   64
# Goiás (GO)                233953.369638   24
# Santa Catarina (SC)       241917.093486   37
# Tocantins (TO)            243002.217032    1
# Bahia (BA)                254368.669275    9
# Sergipe (SE)              328272.278075    1

# %% [markdown]
# #### Para responder a pergunta considerie 2 fatores:
# * `preco`: A melhor escolha é onde o preço é menor.
# * `id`: O estado precisa ter uma quantidade minimamente representativa de oferta.
# * `garantia_de_fabrica`: Filtrei apenas veículos que tem garantia de fábrica pois isso agrega valor ao veículo.
#
# Analisando a tabela acima já filtrada com veiculos que tem garantia de fábrica, e com os fatores preço e oferta, a conclusão é que o melhor Estado para comprar uma picape com transmissão automática é **Minas Gerais (MG)**

# %% [markdown]
# ### c. Qual o melhor estado para se comprar carros que ainda estejam dentro da garantia de fábrica e por quê?

# %%
df_aux = df2.loc[df2['garantia_de_fabrica'] == 1, :]

# %%
df_aux.shape
# Out:
# (4365, 28)

# %%
df_aux1 = df_aux[['estado_vendedor', 'preco', 'id']].groupby('estado_vendedor').agg({'preco': 'mean', 'id': 'count'}).sort_values('preco', ascending=True)
df_aux1
# Out:
#                                   preco    id
# estado_vendedor
# Paraíba (PB)               95762.746630     1
# Pará (PA)                  98156.615283    17
# Amazonas (AM)              99617.303347     9
# Espírito Santo (ES)       104030.208116     9
# Mato Grosso do Sul (MS)   121709.589845    13
# Ceará (CE)                123939.878795     1
# Rio Grande do Norte (RN)  133120.393894     9
# Pernambuco (PE)           149898.416932    20
# Acre (AC)                 150416.911346     2
# Alagoas (AL)              154268.676544    58
# Minas Gerais (MG)         161206.273890   264
# Bahia (BA)                165221.236199    51
# São Paulo (SP)            166751.081004  2307
# Santa Catarina (SC)       173798.439853   330
# Goiás (GO)                174521.413156   186
# Paraná (PR)               175578.245503   389
# Rio Grande do Sul (RS)    176442.236455   281
# Rio de Janeiro (RJ)       179109.858403   412
# Mato Grosso (MT)          197657.066561     2
# Tocantins (TO)            243002.217032     1
# Sergipe (SE)              367138.430255     3

# %% [markdown]
# #### Resposta:
# * Considerando apenas dados de veiculos que ainda estejam dentro da garantia de fabrica e ordenando pela média de preço por estado como mostra a tabela acima, o Estado que tem um numero de ofertas minimamente aceitavel com menor preço médio e portando o melhor para se comprar é o **Pará (PA)**.

# %% [markdown]
# # Data preparation

# %%
df3 = df2.copy()

# %% [markdown]
# ## Split Dataset into train and validation

# %%
X = df3.drop( ['id', 'preco'], axis=1 )
y = df3['preco']

x_train, x_validation, y_train, y_validation = ms.train_test_split( X, y, test_size=0.20, random_state=42 )

df4 = pd.concat( [x_train, y_train], axis=1 )

# %%
df4.shape
# Out:
# (23667, 27)

# %%
df4.dtypes
# Out:
# num_fotos                    int64
# marca                      float64
# modelo                     float64
# versao                     float64
# ano_de_fabricacao          float64
# ano_modelo                 float64
# hodometro                  float64
# cambio                       int32
# num_portas                 float64
# tipo                         int32
# blindado                     int64
# cor                          int32
# cidade_vendedor              int32
# estado_vendedor              int32
# anunciante                   int32
# entrega_delivery             int64
# troca                        int64
# dono_aceita_troca            int64
# veiculo_unico_dono           int64
# revisoes_concessionaria      int64
# ipva_pago                    int64
# veiculo_licenciado           int64
# garantia_de_fabrica          int64
# revisoes_dentro_agenda       int64
# preco                      float64
# tipo_vendedor_PF             uint8
# tipo_vendedor_PJ             uint8
# dtype: object

# %% [markdown]
# ## Rescaling

# %%
mms_num_portas = pp.MinMaxScaler()

# num_portas
df4['num_portas'] = mms_num_portas.fit_transform( df4[['num_portas']].values )
pickle.dump( mms_num_portas, open('/Users/Luan/repos/lighthouse/features/num_portas_scaler.pkl', 'wb' ) )

# %% [markdown]
# ## Encoding

# %%
le_cambio = pp.LabelEncoder()
le_tipo = pp.LabelEncoder()
le_cor = pp.LabelEncoder()
le_cidade_vendedor = pp.LabelEncoder()
le_estado_vendedor = pp.LabelEncoder()
le_anunciante = pp.LabelEncoder()
le_ano_de_fabricacao = pp.LabelEncoder()
le_ano_modelo = pp.LabelEncoder()

# 'cambio' Label Encoder
df4['cambio'] = le_cambio.fit_transform( df4['cambio'] )
pickle.dump( le_cambio, open( '/Users/Luan/repos/lighthouse/features/cambio_scaler.pkl', 'wb' ) )

# 'tipo' Label Encoder
df4['tipo'] = le_tipo.fit_transform( df4['tipo'] )
pickle.dump( le_tipo, open( '/Users/Luan/repos/lighthouse/features/tipo_scaler.pkl', 'wb' ) )

# 'cor' Label Encoder
df4['cor'] = le_cor.fit_transform( df4['cor'] )
pickle.dump( le_cor, open( '/Users/Luan/repos/lighthouse/features/cor_scaler.pkl', 'wb' ) )

# 'cidade_vendedor' Label Encoder
df3['cidade_vendedor'] = le_cidade_vendedor.fit_transform( df3['cidade_vendedor'] )
df4['cidade_vendedor'] = le_cidade_vendedor.transform( df4['cidade_vendedor'] )
pickle.dump( le_cidade_vendedor, open( '/Users/Luan/repos/lighthouse/features/cidade_vendedor_scaler.pkl', 'wb' ) )

# 'estado_vendedor' Label Encoder
df4['estado_vendedor'] = le_estado_vendedor.fit_transform( df4['estado_vendedor'] )
pickle.dump( le_estado_vendedor, open( '/Users/Luan/repos/lighthouse/features/estado_vendedor_scaler.pkl', 'wb' ) )

# 'anunciante' Label Encoder
df4['anunciante'] = le_anunciante.fit_transform( df4['anunciante'] )
pickle.dump( le_anunciante, open( '/Users/Luan/repos/lighthouse/features/anunciante_scaler.pkl', 'wb' ) )

# 'tipo_vendedor' One-Hot Encoding
df4 = pd.get_dummies( df4, prefix=['tipo_vendedor'], columns=['tipo_vendedor'] )

# marca - Target Encoding
target_encode_marca = df4.groupby( 'marca' )['preco'].mean()
df4.loc[:, 'marca'] = df4['marca'].map( target_encode_marca )
pickle.dump( target_encode_marca, open( '/Users/Luan/repos/lighthouse/features/target_encode_marca_scaler.pkl', 'wb' ) )

# modelo - Target Encoding
target_encode_modelo = df4.groupby( 'modelo' )['preco'].mean()
df4.loc[:, 'modelo'] = df4['modelo'].map( target_encode_modelo )
pickle.dump( target_encode_modelo, open( '/Users/Luan/repos/lighthouse/features/target_encode_modelo_scaler.pkl', 'wb' ) )

# versao - Target Encoding
target_encode_versao = df4.groupby( 'versao' )['preco'].mean()
df4.loc[:, 'versao'] = df4['versao'].map( target_encode_versao )
pickle.dump( target_encode_versao, open( '/Users/Luan/repos/lighthouse/features/target_encode_versao_scaler.pkl', 'wb' ) )

# 'ano_de_fabricacao' Label Encoder
df3['ano_de_fabricacao'] = le_ano_de_fabricacao.fit_transform( df3['ano_de_fabricacao'] )
df4['ano_de_fabricacao'] = le_ano_de_fabricacao.transform( df4['ano_de_fabricacao'] )
pickle.dump( le_ano_de_fabricacao, open( '/Users/Luan/repos/lighthouse/features/ano_de_fabricacao_scaler.pkl', 'wb' ) )

# 'ano_modelo' Label Encoder
df3['ano_modelo'] = le_ano_modelo.fit_transform( df3['ano_modelo'] )
df4['ano_modelo'] = le_ano_modelo.transform( df4['ano_modelo'] )
pickle.dump( le_ano_modelo, open( '/Users/Luan/repos/lighthouse/features/ano_modelo_scaler.pkl', 'wb' ) )

# %%
df4.sample(5).T
# Out:
#                                                          3810                                     3610                                    11468                                    7877                                     12388
# id                       5352377931264005947150530261101553542  302319139369158036220313759685806610321  42065866000992187211433272928456275020  125108455784912465549826241707363568226  333428869651606225954540022499641528032
# num_fotos                                                    8                                        8                                      16                                        8                                       15
# marca                                            101172.542178                            222360.778454                           101172.542178                            117786.123964                            160682.881603
# modelo                                            72344.780244                            200593.610808                            75006.417306                            114130.700279                            243930.033385
# versao                                            67702.595747                            193882.161145                            76480.819528                            115721.640809                            245050.180015
# ano_de_fabricacao                                     0.918919                                 0.864865                                0.756757                                 0.891892                                 0.810811
# ano_modelo                                            0.764706                                 0.647059                                0.529412                                 0.705882                                 0.588235
# hodometro                                              44949.0                                  62189.0                                 72725.0                                  78971.0                                  76153.0
# cambio                                                       4                                        2                                       2                                        2                                        2
# num_portas                                                 1.0                                      1.0                                     1.0                                      1.0                                      0.0
# tipo                                                         5                                        6                                       1                                        5                                        4
# blindado                                                     0                                        0                                       0                                        0                                        0
# cor                                                          0                                        4                                       0                                        0                                        0
# cidade_vendedor                                            463                                      463                                     463                                      263                                      463
# estado_vendedor                                             23                                       23                                      23                                       17                                       23
# anunciante                                                   3                                        3                                       2                                        3                                        2
# entrega_delivery                                             0                                        0                                       1                                        0                                        1
# troca                                                        0                                        0                                       1                                        0                                        1
# dono_aceita_troca                                            1                                        1                                       1                                        0                                        1
# veiculo_unico_dono                                           0                                        0                                       0                                        1                                        0
# revisoes_concessionaria                                      1                                        0                                       0                                        0                                        0
# ipva_pago                                                    0                                        1                                       1                                        1                                        0
# veiculo_licenciado                                           0                                        1                                       1                                        1                                        0
# garantia_de_fabrica                                          0                                        0                                       0                                        0                                        0
# revisoes_dentro_agenda                                       0                                        0                                       0                                        0                                        0
# preco                                             85182.164946                            253267.276313                            65202.227494                            106109.519466                            146326.609265
# tipo_vendedor_PF                                             1                                        1                                       0                                        1                                        0
# tipo_vendedor_PJ                                             0                                        0                                       1                                        0                                        1

# %%
correlation = df4.corr( method='pearson')
sns.heatmap( correlation, annot=True );

# %% [markdown]
# ## Validation Preparation

# %%
# num_portas
x_validation['num_portas'] = mms_num_portas.transform( x_validation[['num_portas']].values )

# 'cambio' Label Encoder
x_validation['cambio'] = le_cambio.transform( x_validation['cambio'] )

# 'tipo' Label Encoder
x_validation['tipo'] = le_tipo.transform( x_validation['tipo'] )

# 'cor' Label Encoder
x_validation['cor'] = le_cor.transform( x_validation['cor'] )

# 'cidade_vendedor' Label Encoder
x_validation['cidade_vendedor'] = le_cidade_vendedor.transform( x_validation['cidade_vendedor'] )


# 'estado_vendedor' Label Encoder
x_validation['estado_vendedor'] = le_estado_vendedor.transform( x_validation['estado_vendedor'] )

# 'anunciante' Label Encoder
x_validation['anunciante'] = le_anunciante.transform( x_validation['anunciante'] )

# 'tipo_vendedor' One-Hot Encoding
x_validation = pd.get_dummies( x_validation, prefix=['tipo_vendedor'], columns=['tipo_vendedor'] )

# marca - Target Encoding
x_validation.loc[:, 'marca'] = x_validation['marca'].map( target_encode_marca )

# modelo - Target Encoding
x_validation.loc[:, 'modelo'] = x_validation['modelo'].map( target_encode_modelo )

# versao - Target Encoding
x_validation.loc[:, 'versao'] = x_validation['versao'].map( target_encode_versao )

# 'ano_de_fabricacao' Label Encoder
x_validation['ano_de_fabricacao'] = le_ano_de_fabricacao.transform( x_validation['ano_de_fabricacao'] )

# 'ano_modelo' Label Encoder
x_validation['ano_modelo'] = le_ano_modelo.transform( x_validation['ano_modelo'] )


x_validation = x_validation.fillna( 0 )

# %% [markdown]
# ## Response Variable Transformation

# %%
sns.distplot( df4['preco'] )
# Out:
# <Axes: xlabel='preco', ylabel='Density'>

# %% [markdown]
# A variável resposta possui uma cauda longa à direita, por isso será aplicado transformação logarítmica

# %%
# aplicando log a base de treino 
df4['preco'] = np.log1p( df4['preco'] )

# aplicando log ao teste
y_validation = np.log1p( y_validation )

# %%
sns.distplot( df4['preco'] )
# Out:
# <Axes: xlabel='preco', ylabel='Density'>

# %% [markdown]
# # Feature Selection

# %%
#%%time
## training and test dataset for Boruta
#x_train_n = x_train.values
#y_train_n = y_train.values.ravel()
#
## define RandomForestRegressor
#rf = RandomForestRegressor( n_jobs=-1 )
#
## define Boruta
#boruta = BorutaPy( rf, n_estimators='auto', verbose=2, random_state=42 ).fit( x_train_n, y_train_n)

# %%
#cols_selected = boruta.support_.tolist()
#
## best features
#X_train_fs = X_train.drop( ['date', 'sales'], axis=1 )
#cols_selected_boruta = X_train_fs.iloc[:, cols_selected].columns.to_list()
#
#cols_not_selected_boruta = list(np.setdiff1d(X_train_fs.columns, cols_selected_boruta))

# %%
# Crie o modelo de regressão de floresta aleatória
rf_model = RandomForestRegressor(n_estimators=100, max_depth=5, random_state=42)

# data preparation
x_train_n = x_train.copy()
y_train_n = y_train.values

# Treine o modelo nos dados de treinamento
rf_model.fit( x_train_n, y_train_n )

importances = rf_model.feature_importances_
std = np.std([tree.feature_importances_ for tree in rf_model.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature Ranking:")
df = pd.DataFrame()
for i, j in zip( x_train_n, rf_model.feature_importances_ ):
    aux = pd.DataFrame( {'feature': i, 'importance': j}, index=[0] )
    df = pd.concat([df, aux], axis=0 )
    
print( df.sort_values( 'importance', ascending=False ) )







## Obtenha a importância das características
#importances = rf_model.feature_importances_
#
## Crie um DataFrame para exibir a importância das características
#feature_importance_df = pd.DataFrame({'Feature': range(len(importances)), 'Importance': importances})
#feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
#
## Exiba a importância das características
#print(feature_importance_df)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\IPython\core\interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Luan\AppData\Local\Temp\ipykernel_9256\3900368057.py", line 9, in <module>
#     rf_model.fit( x_train_n, y_train_n )
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\sklearn\base.py", line 1151, in wrapper
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\sklearn\ensemble\_forest.py", line 348, in fit
#     if sample_weight is not None:
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\sklearn\base.py", line 621, in _validate_data
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\sklearn\utils\validation.py", line 1147, in check_X_y
#     y = y.astype(np.float64)
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\sklearn\utils\validation.py", line 917, in check_array
#     % (array.ndim, estimator_name)
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\sklearn\utils\_array_api.py", line 380, in _asarray_with_order
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\pandas\core\generic.py", line 2070, in __array__
#     return np.asarray(self._values, dtype=dtype)
# ValueError: could not convert string to float: 'FORD'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\IPython\core\interactiveshell.py", line 2102, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\IPython\core\ultratb.py", line 1310, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\IPython\core\ultratb.py", line 1199, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\IPython\core\ultratb.py", line 1052, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\IPython\core\ultratb.py", line 978, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\IPython\core\ultratb.py", line 878, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\IPython\core\ultratb.py", line 712, in lines
#     return self._sd.lines
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\stack_data\core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\stack_data\core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\stack_data\core.py", line 628, in executing_piece
#     return only(
#   File "C:\Users\Luan\anaconda3\envs\lighthouse\lib\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
cols_exclude = ['ipva_pago', 'tipo_vendedor_PF','garantia_de_fabrica', 'tipo_vendedor_PJ', 'dono_aceita_troca', 'cambio', 'entrega_delivery', 'veiculo_licenciado', r'evisoes_concessionaria', 'revisoes_dentro_agenda']

# %%
cols_selected = ['num_fotos', 'marca', 'modelo', 'versao', 'ano_de_fabricacao', 'ano_modelo', 'hodometro', 'tipo', 'cor', 'cidade_vendedor', 'estado_vendedor', 'veiculo_unico_dono', 'garantia_de_fabrica']

# %%
df4.head()
# Out:
#        num_fotos          marca         modelo         versao  ano_de_fabricacao  ano_modelo  hodometro  cambio  num_portas  tipo  blindado  cor  cidade_vendedor  estado_vendedor  anunciante  entrega_delivery  troca  dono_aceita_troca  veiculo_unico_dono  revisoes_concessionaria  ipva_pago  veiculo_licenciado  garantia_de_fabrica  revisoes_dentro_agenda      preco  tipo_vendedor_PF  tipo_vendedor_PJ
# 12353          8  129517.003936  192542.211173  212622.531594           0.864865    0.705882    51157.0       2         1.0     4         0    0              243               21           3                 0      0                  1                   0                        1          0                   0                    0                       1  11.916352                 1                 0
# 21201          8   92985.085630  181501.619359  180594.445761           0.864865    0.705882    78636.0       2         1.0     6         0    0              432                3           3                 0      0                  1                   0                        0          0                   0                    0                       0  12.309369                 1                 0
# 28827          8  117786.123964  133762.529896  157928.667479           0.810811    0.647059    83963.0       2         1.0     1         0    0               96               23           3                 0      0                  1                   0                        1          1                   1                    0                       1  11.780754                 1                 0
# 19533          8  160682.881603   95640.461123   95640.461123           0.756757    0.411765    91367.0       2         1.0     1         0    0              432               23           3                 0      0                  1                   0                        0          1                   1                    0                       0  11.061936                 1                 0
# 23111          8  138265.695736  148685.631462  136676.698499           0.891892    0.705882    43630.0       2         1.0     6         1    4              408               23           3                 0      0                  0                   1                        0          1                   1                    0                       0  12.493127                 1                 0

# %%
x_train.columns
# Out:
# Index(['num_fotos', 'marca', 'modelo', 'versao', 'ano_de_fabricacao',
#        'ano_modelo', 'hodometro', 'cambio', 'num_portas', 'tipo', 'blindado',
#        'cor', 'tipo_vendedor', 'cidade_vendedor', 'estado_vendedor',
#        'anunciante', 'entrega_delivery', 'troca', 'dono_aceita_troca',
#        'veiculo_unico_dono', 'revisoes_concessionaria', 'ipva_pago',
#        'veiculo_licenciado', 'garantia_de_fabrica', 'revisoes_dentro_agenda'],
#       dtype='object')

# %% [markdown]
# # Machine Learning Modelling

# %%
x_train = df4.drop(['preco'], axis=1)
y_train = df4['preco']

x_test = x_validation.copy()
y_test = y_validation.copy()

# %% [markdown]
# ## Linear Regression Model

# %%
# model
lr_model = LinearRegression().fit( x_train, y_train )

# prediction
yhat_lr = lr_model.predict( x_test )

# performance
lr_result = ml_error( 'Linear Regression', np.expm1( y_test ), np.expm1( yhat_lr ) )
lr_result
# Out:
#           Model Name           MAE      MAPE          RMSE
# 0  Linear Regression  32940.200188  0.250349  66298.397734

# %%
def cross_validation_regression(model, x_train, y_train, k, verbose=True):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    mae_list = []
    mape_list = []
    rmse_list = []
    i = 1    
    for train_cv, val_cv in kf.split(x_train, y_train):
        if verbose:
            print(f'Fold Number {i}/{k}') 
        else:
            pass

        x_train_fold = x_train.iloc[train_cv]
        y_train_fold = y_train.iloc[train_cv]

        x_val_fold = x_train.iloc[val_cv]
        y_val_fold = y_train.iloc[val_cv]

        # fit model
        model.fit(x_train_fold, y_train_fold)

        # predict
        yhat_model = model.predict(x_val_fold)

        #performance
        m_result = ml_error( model, np.expm1( y_val_fold ), np.expm1( yhat_model ) )
        
        # Calculate regression metrics for the fold
        mae_list.append( m_result[ 'MAE' ] )
        mape_list.append( m_result[ 'MAPE' ] )
        rmse_list.append( m_result[ 'RMSE' ] )
       
        i += 1

    df = pd.DataFrame({'Model Name': type(model).__name__,
                       'MAE Mean': np.round(np.mean(mae_list), 4),
                       'MAPE Mean': np.round(np.mean(mape_list), 4),
                       'RMSE Mean': np.round(np.mean(rmse_list), 4)}, index=[0])
    return df

# %% [markdown]
# ## Random Forest Regressor

# %%
# model
rf_model = RandomForestRegressor(n_estimators=100, n_jobs=-1, random_state=42 ).fit( x_train, y_train )

# prediction
yhat_rf = rf_model.predict( x_test )

# performance
rf_result = ml_error( 'Random Forest Regressor', np.expm1( y_test ), np.expm1( yhat_rf ) )
rf_result
# Out:
#                 Model Name          MAE      MAPE          RMSE
# 0  Random Forest Regressor  27768.28033  0.223227  46190.853721

# %% [markdown]
# ## XGBoost Regressor

# %%
# model
xgb_model = xgb.XGBRegressor().fit( x_train, y_train )

# prediction
yhat_xgb = xgb_model.predict( x_test )

# performance
xgb_result = ml_error( 'XGBoost Regressor', np.expm1( y_test ), np.expm1( yhat_xgb ) )
xgb_result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[259], line 5
#       2 xgb_model = xgb.XGBRegressor().fit( x_train, y_train )
#       4 # prediction
# ----> 5 yhat_xgb = xgb_model.predict( x_test )
#       7 # performance
#       8 xgb_result = ml_error( 'XGBoost Regressor', np.expm1( y_test ), np.expm1( yhat_xgb ) )
#
# File ~\anaconda3\envs\lighthouse\lib\site-packages\xgboost\sklearn.py:1114, in XGBModel.predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1112 if self._can_use_inplace_predict():
#    1113     try:
# -> 1114         predts = self.get_booster().inplace_predict(
#    1115             data=X,
#    1116             iteration_range=iteration_range,
#    1117             predict_type="margin" if output_margin else "value",
#    1118             missing=self.missing,
#    1119             base_margin=base_margin,
#    1120             validate_features=validate_features,
#    1121         )
#    1122         if _is_cupy_array(predts):
#    1123             import cupy  # pylint: disable=import-error
#
# File ~\anaconda3\envs\lighthouse\lib\site-packages\xgboost\core.py:2268, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2264         raise TypeError(
#    2265             "`shape` attribute is required when `validate_features` is True."
#    2266         )
#    2267     if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# -> 2268         raise ValueError(
#    2269             f"Feature shape mismatch, expected: {self.num_features()}, "
#    2270             f"got {data.shape[1]}"
#    2271         )
#    2273 from .data import (
#    2274     _array_interface,
#    2275     _is_cudf_df,
#    (...)
#    2278     _transform_pandas_df,
#    2279 )
#    2281 enable_categorical = _has_categorical(self, data)
#
# ValueError: Feature shape mismatch, expected: 26, got 13

# %% [markdown]
# ## LGBM Regressor

# %%
# model
lgbm_model = lgbm.LGBMRegressor().fit( x_train, y_train )

# prediction
yhat_lgbm = lgbm_model.predict( x_test )

# performance
lgbm_result = ml_error( 'LGBM Regressor', np.expm1( y_test ), np.expm1( yhat_lgbm ) )
lgbm_result
# Out:
#        Model Name           MAE      MAPE          RMSE
# 0  LGBM Regressor  27215.196542  0.217633  45001.671827

# %% [markdown]
# ## CatBoost Regressor

# %%
# model
catb_model = catb.CatBoostRegressor(verbose=False).fit( x_train, y_train )

# prediction
yhat_catb = catb_model.predict( x_test )

# performance
catb_result = ml_error( 'CatBoost Regressor', np.expm1( y_test ), np.expm1( yhat_catb ) )
catb_result
# Out:
#            Model Name           MAE      MAPE          RMSE
# 0  CatBoost Regressor  26878.336688  0.214545  44269.344033

# %% [markdown]
# ## Cross Validation

# %%
models_list = [lr_model, rf_model, xgb_model, lgbm_model, catb_model]
results_list = []

for model in models_list:
    results_model = cross_validation_regression( model, x_train, y_train, 5, verbose=False )
    
    results_list.append(results_model)
    
results_cv = pd.DataFrame(results_list)
    
results_cv
# Out:
#               Model Name    MAE Mean  MAPE Mean    RMSE Mean
# 0       LinearRegression  34981.5552     0.2431  309147.1718
# 1  RandomForestRegressor  25021.8916     0.1982   40480.3874
# 2           XGBRegressor  24796.4334     0.1966   40417.2420
# 3          LGBMRegressor  24432.5371     0.1941   39616.1096
# 4      CatBoostRegressor  24281.1555     0.1929   39523.4232

# %%
#results_cv.to_csv('data/results_cv_cols_sel.csv')

# %% [markdown]
# ## Hyperparameter Fine Tuning

# %%
# Crie o modelo de regressor CatBoost
catboost_model = catb.CatBoostRegressor(iterations=100, random_state=42, verbose=0)

# Defina a grade de hiperparâmetros para a busca aleatória
param_dist = {
    'learning_rate': expon(loc=0.01, scale=0.2),
    'depth': randint(3, 16),
    'l2_leaf_reg': expon(loc=1, scale=10),
    'bagging_temperature': expon(loc=0, scale=1),
    'random_strength': expon(loc=0, scale=1),
    'one_hot_max_size': randint(2, 10),
}

# Realize a busca aleatória com o RandomizedSearchCV
random_search = ms.RandomizedSearchCV(catboost_model, param_distributions=param_dist, n_iter=50, cv=5, scoring='neg_mean_squared_error', random_state=42, verbose=2)
random_search.fit(x_train, y_train)

# Exiba os melhores hiperparâmetros encontrados e o desempenho do modelo
print("Melhores hiperparâmetros:")
print(random_search.best_params_)
print("Melhor MSE:", -random_search.best_score_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END bagging_temperature=0.4692680899768591, depth=15, l2_leaf_reg=3.026485043181491, learning_rate=0.31254483477293715, one_hot_max_size=6, random_strength=0.16962487046234628; total time=  50.5s
# [CV] END bagging_temperature=0.4692680899768591, depth=15, l2_leaf_reg=3.026485043181491, learning_rate=0.31254483477293715, one_hot_max_size=6, random_strength=0.16962487046234628; total time=  50.5s
# [CV] END bagging_temperature=0.4692680899768591, depth=15, l2_leaf_reg=3.026485043181491, learning_rate=0.31254483477293715, one_hot_max_size=6, random_strength=0.16962487046234628; total time=  48.3s
# [CV] END bagging_temperature=0.4692680899768591, depth=15, l2_leaf_reg=3.026485043181491, learning_rate=0.31254483477293715, one_hot_max_size=6, random_strength=0.16962487046234628; total time=  55.1s
# [CV] END bagging_temperature=0.4692680899768591, depth=15, l2_leaf_reg=3.026485043181491, learning_rate=0.31254483477293715, one_hot_max_size=6, random_strength=0.16962487046234628; total time=  52.1s
# [CV] END bagging_temperature=0.16959629191460518, depth=13, l2_leaf_reg=7.147961650819368, learning_rate=0.09120563666275815, one_hot_max_size=9, random_strength=1.2312500617045903; total time=  11.8s
# [CV] END bagging_temperature=0.16959629191460518, depth=13, l2_leaf_reg=7.147961650819368, learning_rate=0.09120563666275815, one_hot_max_size=9, random_strength=1.2312500617045903; total time=  12.1s
# [CV] END bagging_temperature=0.16959629191460518, depth=13, l2_leaf_reg=7.147961650819368, learning_rate=0.09120563666275815, one_hot_max_size=9, random_strength=1.2312500617045903; total time=  12.2s
# [CV] END bagging_temperature=0.16959629191460518, depth=13, l2_leaf_reg=7.147961650819368, learning_rate=0.09120563666275815, one_hot_max_size=9, random_strength=1.2312500617045903; total time=  11.4s
# [CV] END bagging_temperature=0.16959629191460518, depth=13, l2_leaf_reg=7.147961650819368, learning_rate=0.09120563666275815, one_hot_max_size=9, random_strength=1.2312500617045903; total time=  11.7s
# [CV] END bagging_temperature=0.020799307999138622, depth=4, l2_leaf_reg=13.80129748994866, learning_rate=0.5679151057639624, one_hot_max_size=3, random_strength=0.20067898874966336; total time=   0.2s
# [CV] END bagging_temperature=0.020799307999138622, depth=4, l2_leaf_reg=13.80129748994866, learning_rate=0.5679151057639624, one_hot_max_size=3, random_strength=0.20067898874966336; total time=   0.2s
# [CV] END bagging_temperature=0.020799307999138622, depth=4, l2_leaf_reg=13.80129748994866, learning_rate=0.5679151057639624, one_hot_max_size=3, random_strength=0.20067898874966336; total time=   0.2s
# [CV] END bagging_temperature=0.020799307999138622, depth=4, l2_leaf_reg=13.80129748994866, learning_rate=0.5679151057639624, one_hot_max_size=3, random_strength=0.20067898874966336; total time=   0.3s
# [CV] END bagging_temperature=0.020799307999138622, depth=4, l2_leaf_reg=13.80129748994866, learning_rate=0.5679151057639624, one_hot_max_size=3, random_strength=0.20067898874966336; total time=   0.3s
# [CV] END bagging_temperature=0.20261142283225705, depth=14, l2_leaf_reg=10.45856422396747, learning_rate=0.011418277958893969, one_hot_max_size=2, random_strength=0.3442229925539415; total time=  25.9s
# [CV] END bagging_temperature=0.20261142283225705, depth=14, l2_leaf_reg=10.45856422396747, learning_rate=0.011418277958893969, one_hot_max_size=2, random_strength=0.3442229925539415; total time=  23.3s
# [CV] END bagging_temperature=0.20261142283225705, depth=14, l2_leaf_reg=10.45856422396747, learning_rate=0.011418277958893969, one_hot_max_size=2, random_strength=0.3442229925539415; total time=  22.5s
# [CV] END bagging_temperature=0.20261142283225705, depth=14, l2_leaf_reg=10.45856422396747, learning_rate=0.011418277958893969, one_hot_max_size=2, random_strength=0.3442229925539415; total time=  24.0s
# [CV] END bagging_temperature=0.20261142283225705, depth=14, l2_leaf_reg=10.45856422396747, learning_rate=0.011418277958893969, one_hot_max_size=2, random_strength=0.3442229925539415; total time=  24.0s
# [CV] END bagging_temperature=0.9463708738997987, depth=12, l2_leaf_reg=1.4778961126377175, learning_rate=0.7380599107255521, one_hot_max_size=8, random_strength=0.608934687859775; total time=   6.4s
# [CV] END bagging_temperature=0.9463708738997987, depth=12, l2_leaf_reg=1.4778961126377175, learning_rate=0.7380599107255521, one_hot_max_size=8, random_strength=0.608934687859775; total time=   7.0s
# [CV] END bagging_temperature=0.9463708738997987, depth=12, l2_leaf_reg=1.4778961126377175, learning_rate=0.7380599107255521, one_hot_max_size=8, random_strength=0.608934687859775; total time=   6.4s
# [CV] END bagging_temperature=0.9463708738997987, depth=12, l2_leaf_reg=1.4778961126377175, learning_rate=0.7380599107255521, one_hot_max_size=8, random_strength=0.608934687859775; total time=   6.8s
# [CV] END bagging_temperature=0.9463708738997987, depth=12, l2_leaf_reg=1.4778961126377175, learning_rate=0.7380599107255521, one_hot_max_size=8, random_strength=0.608934687859775; total time=   6.5s
# [CV] END bagging_temperature=1.537936011030912, depth=5, l2_leaf_reg=5.820146597705036, learning_rate=0.8276433050919392, one_hot_max_size=2, random_strength=0.047563849756408545; total time=   0.3s
# [CV] END bagging_temperature=1.537936011030912, depth=5, l2_leaf_reg=5.820146597705036, learning_rate=0.8276433050919392, one_hot_max_size=2, random_strength=0.047563849756408545; total time=   0.3s
# [CV] END bagging_temperature=1.537936011030912, depth=5, l2_leaf_reg=5.820146597705036, learning_rate=0.8276433050919392, one_hot_max_size=2, random_strength=0.047563849756408545; total time=   0.3s
# [CV] END bagging_temperature=1.537936011030912, depth=5, l2_leaf_reg=5.820146597705036, learning_rate=0.8276433050919392, one_hot_max_size=2, random_strength=0.047563849756408545; total time=   0.3s
# [CV] END bagging_temperature=1.537936011030912, depth=5, l2_leaf_reg=5.820146597705036, learning_rate=0.8276433050919392, one_hot_max_size=2, random_strength=0.047563849756408545; total time=   0.3s
# [CV] END bagging_temperature=0.9353330206496101, depth=7, l2_leaf_reg=6.9874514384647215, learning_rate=0.012670745322249825, one_hot_max_size=2, random_strength=3.3706303424611725; total time=   0.4s
# [CV] END bagging_temperature=0.9353330206496101, depth=7, l2_leaf_reg=6.9874514384647215, learning_rate=0.012670745322249825, one_hot_max_size=2, random_strength=3.3706303424611725; total time=   0.4s
# [CV] END bagging_temperature=0.9353330206496101, depth=7, l2_leaf_reg=6.9874514384647215, learning_rate=0.012670745322249825, one_hot_max_size=2, random_strength=3.3706303424611725; total time=   0.4s
# [CV] END bagging_temperature=0.9353330206496101, depth=7, l2_leaf_reg=6.9874514384647215, learning_rate=0.012670745322249825, one_hot_max_size=2, random_strength=3.3706303424611725; total time=   0.4s
# [CV] END bagging_temperature=0.9353330206496101, depth=7, l2_leaf_reg=6.9874514384647215, learning_rate=0.012670745322249825, one_hot_max_size=2, random_strength=3.3706303424611725; total time=   0.4s
# [CV] END bagging_temperature=1.6523315728128767, depth=11, l2_leaf_reg=1.160950859938234, learning_rate=0.06250525017907556, one_hot_max_size=5, random_strength=0.5800908425853983; total time=   3.9s
# [CV] END bagging_temperature=1.6523315728128767, depth=11, l2_leaf_reg=1.160950859938234, learning_rate=0.06250525017907556, one_hot_max_size=5, random_strength=0.5800908425853983; total time=   3.8s
# [CV] END bagging_temperature=1.6523315728128767, depth=11, l2_leaf_reg=1.160950859938234, learning_rate=0.06250525017907556, one_hot_max_size=5, random_strength=0.5800908425853983; total time=   3.4s
# [CV] END bagging_temperature=1.6523315728128767, depth=11, l2_leaf_reg=1.160950859938234, learning_rate=0.06250525017907556, one_hot_max_size=5, random_strength=0.5800908425853983; total time=   3.4s
# [CV] END bagging_temperature=1.6523315728128767, depth=11, l2_leaf_reg=1.160950859938234, learning_rate=0.06250525017907556, one_hot_max_size=5, random_strength=0.5800908425853983; total time=   3.5s
# [CV] END bagging_temperature=0.13015223395444864, depth=15, l2_leaf_reg=18.909292843438934, learning_rate=0.04807832330334998, one_hot_max_size=2, random_strength=0.2994577768406861; total time=  48.6s
# [CV] END bagging_temperature=0.13015223395444864, depth=15, l2_leaf_reg=18.909292843438934, learning_rate=0.04807832330334998, one_hot_max_size=2, random_strength=0.2994577768406861; total time=  48.0s
# [CV] END bagging_temperature=0.13015223395444864, depth=15, l2_leaf_reg=18.909292843438934, learning_rate=0.04807832330334998, one_hot_max_size=2, random_strength=0.2994577768406861; total time=  48.8s
# [CV] END bagging_temperature=0.13015223395444864, depth=15, l2_leaf_reg=18.909292843438934, learning_rate=0.04807832330334998, one_hot_max_size=2, random_strength=0.2994577768406861; total time=  49.6s
# [CV] END bagging_temperature=0.13015223395444864, depth=15, l2_leaf_reg=18.909292843438934, learning_rate=0.04807832330334998, one_hot_max_size=2, random_strength=0.2994577768406861; total time=  48.6s
# [CV] END bagging_temperature=1.0862557985649803, depth=4, l2_leaf_reg=6.536563610069876, learning_rate=0.056624046377123406, one_hot_max_size=5, random_strength=0.20438859950790575; total time=   0.2s
# [CV] END bagging_temperature=1.0862557985649803, depth=4, l2_leaf_reg=6.536563610069876, learning_rate=0.056624046377123406, one_hot_max_size=5, random_strength=0.20438859950790575; total time=   0.2s
# [CV] END bagging_temperature=1.0862557985649803, depth=4, l2_leaf_reg=6.536563610069876, learning_rate=0.056624046377123406, one_hot_max_size=5, random_strength=0.20438859950790575; total time=   0.2s
# [CV] END bagging_temperature=1.0862557985649803, depth=4, l2_leaf_reg=6.536563610069876, learning_rate=0.056624046377123406, one_hot_max_size=5, random_strength=0.20438859950790575; total time=   0.2s
# [CV] END bagging_temperature=1.0862557985649803, depth=4, l2_leaf_reg=6.536563610069876, learning_rate=0.056624046377123406, one_hot_max_size=5, random_strength=0.20438859950790575; total time=   0.2s
# [CV] END bagging_temperature=3.4928071327362264, depth=12, l2_leaf_reg=6.973900704070795, learning_rate=0.11055503515174782, one_hot_max_size=5, random_strength=0.911054412383275; total time=   6.0s
# [CV] END bagging_temperature=3.4928071327362264, depth=12, l2_leaf_reg=6.973900704070795, learning_rate=0.11055503515174782, one_hot_max_size=5, random_strength=0.911054412383275; total time=   6.9s
# [CV] END bagging_temperature=3.4928071327362264, depth=12, l2_leaf_reg=6.973900704070795, learning_rate=0.11055503515174782, one_hot_max_size=5, random_strength=0.911054412383275; total time=   6.2s
# [CV] END bagging_temperature=3.4928071327362264, depth=12, l2_leaf_reg=6.973900704070795, learning_rate=0.11055503515174782, one_hot_max_size=5, random_strength=0.911054412383275; total time=   6.1s
# [CV] END bagging_temperature=3.4928071327362264, depth=12, l2_leaf_reg=6.973900704070795, learning_rate=0.11055503515174782, one_hot_max_size=5, random_strength=0.911054412383275; total time=   6.9s
# [CV] END bagging_temperature=2.549435379269405, depth=10, l2_leaf_reg=9.45003102305618, learning_rate=0.15714174578950954, one_hot_max_size=7, random_strength=0.3935320868030868; total time=   1.9s
# [CV] END bagging_temperature=2.549435379269405, depth=10, l2_leaf_reg=9.45003102305618, learning_rate=0.15714174578950954, one_hot_max_size=7, random_strength=0.3935320868030868; total time=   1.8s
# [CV] END bagging_temperature=2.549435379269405, depth=10, l2_leaf_reg=9.45003102305618, learning_rate=0.15714174578950954, one_hot_max_size=7, random_strength=0.3935320868030868; total time=   2.0s
# [CV] END bagging_temperature=2.549435379269405, depth=10, l2_leaf_reg=9.45003102305618, learning_rate=0.15714174578950954, one_hot_max_size=7, random_strength=0.3935320868030868; total time=   1.8s
# [CV] END bagging_temperature=2.549435379269405, depth=10, l2_leaf_reg=9.45003102305618, learning_rate=0.15714174578950954, one_hot_max_size=7, random_strength=0.3935320868030868; total time=   2.1s
# [CV] END bagging_temperature=0.4921302917942186, depth=4, l2_leaf_reg=8.758597359502012, learning_rate=0.1867410726016295, one_hot_max_size=2, random_strength=0.3298028401342492; total time=   0.3s
# [CV] END bagging_temperature=0.4921302917942186, depth=4, l2_leaf_reg=8.758597359502012, learning_rate=0.1867410726016295, one_hot_max_size=2, random_strength=0.3298028401342492; total time=   0.3s
# [CV] END bagging_temperature=0.4921302917942186, depth=4, l2_leaf_reg=8.758597359502012, learning_rate=0.1867410726016295, one_hot_max_size=2, random_strength=0.3298028401342492; total time=   0.3s
# [CV] END bagging_temperature=0.4921302917942186, depth=4, l2_leaf_reg=8.758597359502012, learning_rate=0.1867410726016295, one_hot_max_size=2, random_strength=0.3298028401342492; total time=   0.3s
# [CV] END bagging_temperature=0.4921302917942186, depth=4, l2_leaf_reg=8.758597359502012, learning_rate=0.1867410726016295, one_hot_max_size=2, random_strength=0.3298028401342492; total time=   0.3s
# [CV] END bagging_temperature=0.782407083207746, depth=11, l2_leaf_reg=4.513655007312835, learning_rate=0.04612865854856514, one_hot_max_size=2, random_strength=4.33414633958732; total time=   3.0s
# [CV] END bagging_temperature=0.782407083207746, depth=11, l2_leaf_reg=4.513655007312835, learning_rate=0.04612865854856514, one_hot_max_size=2, random_strength=4.33414633958732; total time=   3.7s
# [CV] END bagging_temperature=0.782407083207746, depth=11, l2_leaf_reg=4.513655007312835, learning_rate=0.04612865854856514, one_hot_max_size=2, random_strength=4.33414633958732; total time=   3.3s
# [CV] END bagging_temperature=0.782407083207746, depth=11, l2_leaf_reg=4.513655007312835, learning_rate=0.04612865854856514, one_hot_max_size=2, random_strength=4.33414633958732; total time=   3.9s
# [CV] END bagging_temperature=0.782407083207746, depth=11, l2_leaf_reg=4.513655007312835, learning_rate=0.04612865854856514, one_hot_max_size=2, random_strength=4.33414633958732; total time=   3.8s
# [CV] END bagging_temperature=1.4794837762415114, depth=14, l2_leaf_reg=4.474153391604592, learning_rate=0.012835976751422989, one_hot_max_size=4, random_strength=1.2270959073870447; total time=  22.1s
# [CV] END bagging_temperature=1.4794837762415114, depth=14, l2_leaf_reg=4.474153391604592, learning_rate=0.012835976751422989, one_hot_max_size=4, random_strength=1.2270959073870447; total time=  23.8s
# [CV] END bagging_temperature=1.4794837762415114, depth=14, l2_leaf_reg=4.474153391604592, learning_rate=0.012835976751422989, one_hot_max_size=4, random_strength=1.2270959073870447; total time=  23.0s
# [CV] END bagging_temperature=1.4794837762415114, depth=14, l2_leaf_reg=4.474153391604592, learning_rate=0.012835976751422989, one_hot_max_size=4, random_strength=1.2270959073870447; total time=  23.7s
# [CV] END bagging_temperature=1.4794837762415114, depth=14, l2_leaf_reg=4.474153391604592, learning_rate=0.012835976751422989, one_hot_max_size=4, random_strength=1.2270959073870447; total time=  23.4s
# [CV] END bagging_temperature=1.305662908787999, depth=3, l2_leaf_reg=10.31302787993573, learning_rate=0.5315528799969487, one_hot_max_size=3, random_strength=0.12315010460444965; total time=   0.2s
# [CV] END bagging_temperature=1.305662908787999, depth=3, l2_leaf_reg=10.31302787993573, learning_rate=0.5315528799969487, one_hot_max_size=3, random_strength=0.12315010460444965; total time=   0.2s
# [CV] END bagging_temperature=1.305662908787999, depth=3, l2_leaf_reg=10.31302787993573, learning_rate=0.5315528799969487, one_hot_max_size=3, random_strength=0.12315010460444965; total time=   0.2s
# [CV] END bagging_temperature=1.305662908787999, depth=3, l2_leaf_reg=10.31302787993573, learning_rate=0.5315528799969487, one_hot_max_size=3, random_strength=0.12315010460444965; total time=   0.2s
# [CV] END bagging_temperature=1.305662908787999, depth=3, l2_leaf_reg=10.31302787993573, learning_rate=0.5315528799969487, one_hot_max_size=3, random_strength=0.12315010460444965; total time=   0.2s
# [CV] END bagging_temperature=1.9885295716582227, depth=10, l2_leaf_reg=6.968387249046296, learning_rate=0.030054721077261003, one_hot_max_size=8, random_strength=0.3724883504103537; total time=   2.0s
# [CV] END bagging_temperature=1.9885295716582227, depth=10, l2_leaf_reg=6.968387249046296, learning_rate=0.030054721077261003, one_hot_max_size=8, random_strength=0.3724883504103537; total time=   1.9s
# [CV] END bagging_temperature=1.9885295716582227, depth=10, l2_leaf_reg=6.968387249046296, learning_rate=0.030054721077261003, one_hot_max_size=8, random_strength=0.3724883504103537; total time=   2.2s
# [CV] END bagging_temperature=1.9885295716582227, depth=10, l2_leaf_reg=6.968387249046296, learning_rate=0.030054721077261003, one_hot_max_size=8, random_strength=0.3724883504103537; total time=   2.4s
# [CV] END bagging_temperature=1.9885295716582227, depth=10, l2_leaf_reg=6.968387249046296, learning_rate=0.030054721077261003, one_hot_max_size=8, random_strength=0.3724883504103537; total time=   1.9s
# [CV] END bagging_temperature=0.39331421318413134, depth=5, l2_leaf_reg=9.947684754285794, learning_rate=0.07423999278552834, one_hot_max_size=4, random_strength=0.6390661333763098; total time=   0.3s
# [CV] END bagging_temperature=0.39331421318413134, depth=5, l2_leaf_reg=9.947684754285794, learning_rate=0.07423999278552834, one_hot_max_size=4, random_strength=0.6390661333763098; total time=   0.3s
# [CV] END bagging_temperature=0.39331421318413134, depth=5, l2_leaf_reg=9.947684754285794, learning_rate=0.07423999278552834, one_hot_max_size=4, random_strength=0.6390661333763098; total time=   0.3s
# [CV] END bagging_temperature=0.39331421318413134, depth=5, l2_leaf_reg=9.947684754285794, learning_rate=0.07423999278552834, one_hot_max_size=4, random_strength=0.6390661333763098; total time=   0.3s
# [CV] END bagging_temperature=0.39331421318413134, depth=5, l2_leaf_reg=9.947684754285794, learning_rate=0.07423999278552834, one_hot_max_size=4, random_strength=0.6390661333763098; total time=   0.3s
# [CV] END bagging_temperature=0.1273723936155019, depth=5, l2_leaf_reg=15.303927530768641, learning_rate=0.17477749897716577, one_hot_max_size=8, random_strength=0.2958060800342772; total time=   0.3s
# [CV] END bagging_temperature=0.1273723936155019, depth=5, l2_leaf_reg=15.303927530768641, learning_rate=0.17477749897716577, one_hot_max_size=8, random_strength=0.2958060800342772; total time=   0.3s
# [CV] END bagging_temperature=0.1273723936155019, depth=5, l2_leaf_reg=15.303927530768641, learning_rate=0.17477749897716577, one_hot_max_size=8, random_strength=0.2958060800342772; total time=   0.3s
# [CV] END bagging_temperature=0.1273723936155019, depth=5, l2_leaf_reg=15.303927530768641, learning_rate=0.17477749897716577, one_hot_max_size=8, random_strength=0.2958060800342772; total time=   0.3s
# [CV] END bagging_temperature=0.1273723936155019, depth=5, l2_leaf_reg=15.303927530768641, learning_rate=0.17477749897716577, one_hot_max_size=8, random_strength=0.2958060800342772; total time=   0.3s
# [CV] END bagging_temperature=0.04127375231664331, depth=12, l2_leaf_reg=1.2574777399011374, learning_rate=0.03283348703837317, one_hot_max_size=8, random_strength=2.261093840942367; total time=   5.6s
# [CV] END bagging_temperature=0.04127375231664331, depth=12, l2_leaf_reg=1.2574777399011374, learning_rate=0.03283348703837317, one_hot_max_size=8, random_strength=2.261093840942367; total time=   6.6s
# [CV] END bagging_temperature=0.04127375231664331, depth=12, l2_leaf_reg=1.2574777399011374, learning_rate=0.03283348703837317, one_hot_max_size=8, random_strength=2.261093840942367; total time=   6.7s
# [CV] END bagging_temperature=0.04127375231664331, depth=12, l2_leaf_reg=1.2574777399011374, learning_rate=0.03283348703837317, one_hot_max_size=8, random_strength=2.261093840942367; total time=   7.6s
# [CV] END bagging_temperature=0.04127375231664331, depth=12, l2_leaf_reg=1.2574777399011374, learning_rate=0.03283348703837317, one_hot_max_size=8, random_strength=2.261093840942367; total time=   5.9s
# [CV] END bagging_temperature=0.6450624521653773, depth=15, l2_leaf_reg=8.104371771341901, learning_rate=0.48625310596919513, one_hot_max_size=8, random_strength=0.9273956116389813; total time=  49.0s
# [CV] END bagging_temperature=0.6450624521653773, depth=15, l2_leaf_reg=8.104371771341901, learning_rate=0.48625310596919513, one_hot_max_size=8, random_strength=0.9273956116389813; total time=  50.7s
# [CV] END bagging_temperature=0.6450624521653773, depth=15, l2_leaf_reg=8.104371771341901, learning_rate=0.48625310596919513, one_hot_max_size=8, random_strength=0.9273956116389813; total time=  53.7s
# [CV] END bagging_temperature=0.6450624521653773, depth=15, l2_leaf_reg=8.104371771341901, learning_rate=0.48625310596919513, one_hot_max_size=8, random_strength=0.9273956116389813; total time=  54.9s
# [CV] END bagging_temperature=0.6450624521653773, depth=15, l2_leaf_reg=8.104371771341901, learning_rate=0.48625310596919513, one_hot_max_size=8, random_strength=0.9273956116389813; total time=  52.1s
# [CV] END bagging_temperature=0.7761833954623697, depth=15, l2_leaf_reg=3.5980515691739403, learning_rate=0.026020855710035276, one_hot_max_size=4, random_strength=1.1867386132926785; total time=  48.7s
# [CV] END bagging_temperature=0.7761833954623697, depth=15, l2_leaf_reg=3.5980515691739403, learning_rate=0.026020855710035276, one_hot_max_size=4, random_strength=1.1867386132926785; total time=  50.6s
# [CV] END bagging_temperature=0.7761833954623697, depth=15, l2_leaf_reg=3.5980515691739403, learning_rate=0.026020855710035276, one_hot_max_size=4, random_strength=1.1867386132926785; total time=  49.6s
# [CV] END bagging_temperature=0.7761833954623697, depth=15, l2_leaf_reg=3.5980515691739403, learning_rate=0.026020855710035276, one_hot_max_size=4, random_strength=1.1867386132926785; total time=  48.2s
# [CV] END bagging_temperature=0.7761833954623697, depth=15, l2_leaf_reg=3.5980515691739403, learning_rate=0.026020855710035276, one_hot_max_size=4, random_strength=1.1867386132926785; total time=  50.1s
# [CV] END bagging_temperature=2.124169814240007, depth=12, l2_leaf_reg=17.508870804845696, learning_rate=0.21069883810410622, one_hot_max_size=7, random_strength=0.6097891815881622; total time=   6.3s
# [CV] END bagging_temperature=2.124169814240007, depth=12, l2_leaf_reg=17.508870804845696, learning_rate=0.21069883810410622, one_hot_max_size=7, random_strength=0.6097891815881622; total time=   7.1s
# [CV] END bagging_temperature=2.124169814240007, depth=12, l2_leaf_reg=17.508870804845696, learning_rate=0.21069883810410622, one_hot_max_size=7, random_strength=0.6097891815881622; total time=   6.3s
# [CV] END bagging_temperature=2.124169814240007, depth=12, l2_leaf_reg=17.508870804845696, learning_rate=0.21069883810410622, one_hot_max_size=7, random_strength=0.6097891815881622; total time=   6.6s
# [CV] END bagging_temperature=2.124169814240007, depth=12, l2_leaf_reg=17.508870804845696, learning_rate=0.21069883810410622, one_hot_max_size=7, random_strength=0.6097891815881622; total time=   6.8s
# [CV] END bagging_temperature=0.24646391605155396, depth=6, l2_leaf_reg=23.308134052355612, learning_rate=0.1650199803932344, one_hot_max_size=3, random_strength=0.1302088665616574; total time=   0.3s
# [CV] END bagging_temperature=0.24646391605155396, depth=6, l2_leaf_reg=23.308134052355612, learning_rate=0.1650199803932344, one_hot_max_size=3, random_strength=0.1302088665616574; total time=   0.3s
# [CV] END bagging_temperature=0.24646391605155396, depth=6, l2_leaf_reg=23.308134052355612, learning_rate=0.1650199803932344, one_hot_max_size=3, random_strength=0.1302088665616574; total time=   0.3s
# [CV] END bagging_temperature=0.24646391605155396, depth=6, l2_leaf_reg=23.308134052355612, learning_rate=0.1650199803932344, one_hot_max_size=3, random_strength=0.1302088665616574; total time=   0.3s
# [CV] END bagging_temperature=0.24646391605155396, depth=6, l2_leaf_reg=23.308134052355612, learning_rate=0.1650199803932344, one_hot_max_size=3, random_strength=0.1302088665616574; total time=   0.3s
# [CV] END bagging_temperature=0.4405191413413164, depth=3, l2_leaf_reg=4.176359085304841, learning_rate=0.21864883025686888, one_hot_max_size=2, random_strength=1.703829726638945; total time=   0.2s
# [CV] END bagging_temperature=0.4405191413413164, depth=3, l2_leaf_reg=4.176359085304841, learning_rate=0.21864883025686888, one_hot_max_size=2, random_strength=1.703829726638945; total time=   0.2s
# [CV] END bagging_temperature=0.4405191413413164, depth=3, l2_leaf_reg=4.176359085304841, learning_rate=0.21864883025686888, one_hot_max_size=2, random_strength=1.703829726638945; total time=   0.2s
# [CV] END bagging_temperature=0.4405191413413164, depth=3, l2_leaf_reg=4.176359085304841, learning_rate=0.21864883025686888, one_hot_max_size=2, random_strength=1.703829726638945; total time=   0.2s
# [CV] END bagging_temperature=0.4405191413413164, depth=3, l2_leaf_reg=4.176359085304841, learning_rate=0.21864883025686888, one_hot_max_size=2, random_strength=1.703829726638945; total time=   0.2s
# [CV] END bagging_temperature=1.9713449718798333, depth=9, l2_leaf_reg=2.799114871179353, learning_rate=0.16275231006818694, one_hot_max_size=7, random_strength=0.2511673382758245; total time=   1.1s
# [CV] END bagging_temperature=1.9713449718798333, depth=9, l2_leaf_reg=2.799114871179353, learning_rate=0.16275231006818694, one_hot_max_size=7, random_strength=0.2511673382758245; total time=   0.9s
# [CV] END bagging_temperature=1.9713449718798333, depth=9, l2_leaf_reg=2.799114871179353, learning_rate=0.16275231006818694, one_hot_max_size=7, random_strength=0.2511673382758245; total time=   1.0s
# [CV] END bagging_temperature=1.9713449718798333, depth=9, l2_leaf_reg=2.799114871179353, learning_rate=0.16275231006818694, one_hot_max_size=7, random_strength=0.2511673382758245; total time=   1.1s
# [CV] END bagging_temperature=1.9713449718798333, depth=9, l2_leaf_reg=2.799114871179353, learning_rate=0.16275231006818694, one_hot_max_size=7, random_strength=0.2511673382758245; total time=   1.4s
# [CV] END bagging_temperature=0.1276803915456468, depth=14, l2_leaf_reg=3.7987995130717196, learning_rate=0.04685454193256562, one_hot_max_size=9, random_strength=0.7314528057601519; total time=  24.8s
# [CV] END bagging_temperature=0.1276803915456468, depth=14, l2_leaf_reg=3.7987995130717196, learning_rate=0.04685454193256562, one_hot_max_size=9, random_strength=0.7314528057601519; total time=  25.0s
# [CV] END bagging_temperature=0.1276803915456468, depth=14, l2_leaf_reg=3.7987995130717196, learning_rate=0.04685454193256562, one_hot_max_size=9, random_strength=0.7314528057601519; total time=  25.0s
# [CV] END bagging_temperature=0.1276803915456468, depth=14, l2_leaf_reg=3.7987995130717196, learning_rate=0.04685454193256562, one_hot_max_size=9, random_strength=0.7314528057601519; total time=  25.4s
# [CV] END bagging_temperature=0.1276803915456468, depth=14, l2_leaf_reg=3.7987995130717196, learning_rate=0.04685454193256562, one_hot_max_size=9, random_strength=0.7314528057601519; total time=  24.0s
# [CV] END bagging_temperature=1.2140869768808549, depth=3, l2_leaf_reg=1.6709351259978942, learning_rate=0.0685832598118217, one_hot_max_size=5, random_strength=0.2900612949922053; total time=   0.2s
# [CV] END bagging_temperature=1.2140869768808549, depth=3, l2_leaf_reg=1.6709351259978942, learning_rate=0.0685832598118217, one_hot_max_size=5, random_strength=0.2900612949922053; total time=   0.2s
# [CV] END bagging_temperature=1.2140869768808549, depth=3, l2_leaf_reg=1.6709351259978942, learning_rate=0.0685832598118217, one_hot_max_size=5, random_strength=0.2900612949922053; total time=   0.2s
# [CV] END bagging_temperature=1.2140869768808549, depth=3, l2_leaf_reg=1.6709351259978942, learning_rate=0.0685832598118217, one_hot_max_size=5, random_strength=0.2900612949922053; total time=   0.2s
# [CV] END bagging_temperature=1.2140869768808549, depth=3, l2_leaf_reg=1.6709351259978942, learning_rate=0.0685832598118217, one_hot_max_size=5, random_strength=0.2900612949922053; total time=   0.2s
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# [CV] END bagging_temperature=0.6876592784638472, depth=3, l2_leaf_reg=2.6027078782001993, learning_rate=1.2285210224316896, one_hot_max_size=4, random_strength=0.9404920709825931; total time=   0.3s
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# [CV] END bagging_temperature=0.6876592784638472, depth=3, l2_leaf_reg=2.6027078782001993, learning_rate=1.2285210224316896, one_hot_max_size=4, random_strength=0.9404920709825931; total time=   0.2s
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# [CV] END bagging_temperature=0.6876592784638472, depth=3, l2_leaf_reg=2.6027078782001993, learning_rate=1.2285210224316896, one_hot_max_size=4, random_strength=0.9404920709825931; total time=   0.2s
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# [CV] END bagging_temperature=0.6876592784638472, depth=3, l2_leaf_reg=2.6027078782001993, learning_rate=1.2285210224316896, one_hot_max_size=4, random_strength=0.9404920709825931; total time=   0.2s
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# learning rate is greater than 1. You probably need to decrease learning rate.
# [CV] END bagging_temperature=0.6876592784638472, depth=3, l2_leaf_reg=2.6027078782001993, learning_rate=1.2285210224316896, one_hot_max_size=4, random_strength=0.9404920709825931; total time=   0.2s
# [CV] END bagging_temperature=0.6985196328296385, depth=8, l2_leaf_reg=1.336092491249399, learning_rate=0.09464576497532753, one_hot_max_size=2, random_strength=0.27386055214207705; total time=   0.8s
# [CV] END bagging_temperature=0.6985196328296385, depth=8, l2_leaf_reg=1.336092491249399, learning_rate=0.09464576497532753, one_hot_max_size=2, random_strength=0.27386055214207705; total time=   0.7s
# [CV] END bagging_temperature=0.6985196328296385, depth=8, l2_leaf_reg=1.336092491249399, learning_rate=0.09464576497532753, one_hot_max_size=2, random_strength=0.27386055214207705; total time=   0.6s
# [CV] END bagging_temperature=0.6985196328296385, depth=8, l2_leaf_reg=1.336092491249399, learning_rate=0.09464576497532753, one_hot_max_size=2, random_strength=0.27386055214207705; total time=   0.6s
# [CV] END bagging_temperature=0.6985196328296385, depth=8, l2_leaf_reg=1.336092491249399, learning_rate=0.09464576497532753, one_hot_max_size=2, random_strength=0.27386055214207705; total time=   0.7s
# [CV] END bagging_temperature=0.15653086098546976, depth=14, l2_leaf_reg=6.938144920353857, learning_rate=0.17099150772582328, one_hot_max_size=8, random_strength=1.1151550102972934; total time=  22.4s
# [CV] END bagging_temperature=0.15653086098546976, depth=14, l2_leaf_reg=6.938144920353857, learning_rate=0.17099150772582328, one_hot_max_size=8, random_strength=1.1151550102972934; total time=  23.5s
# [CV] END bagging_temperature=0.15653086098546976, depth=14, l2_leaf_reg=6.938144920353857, learning_rate=0.17099150772582328, one_hot_max_size=8, random_strength=1.1151550102972934; total time=  23.0s
# [CV] END bagging_temperature=0.15653086098546976, depth=14, l2_leaf_reg=6.938144920353857, learning_rate=0.17099150772582328, one_hot_max_size=8, random_strength=1.1151550102972934; total time=  23.2s
# [CV] END bagging_temperature=0.15653086098546976, depth=14, l2_leaf_reg=6.938144920353857, learning_rate=0.17099150772582328, one_hot_max_size=8, random_strength=1.1151550102972934; total time=  23.4s
# [CV] END bagging_temperature=1.4338876262394629, depth=13, l2_leaf_reg=3.7728291596947163, learning_rate=0.33505224505042003, one_hot_max_size=6, random_strength=1.0005037477317713; total time=  12.5s
# [CV] END bagging_temperature=1.4338876262394629, depth=13, l2_leaf_reg=3.7728291596947163, learning_rate=0.33505224505042003, one_hot_max_size=6, random_strength=1.0005037477317713; total time=  11.8s
# [CV] END bagging_temperature=1.4338876262394629, depth=13, l2_leaf_reg=3.7728291596947163, learning_rate=0.33505224505042003, one_hot_max_size=6, random_strength=1.0005037477317713; total time=  11.8s
# [CV] END bagging_temperature=1.4338876262394629, depth=13, l2_leaf_reg=3.7728291596947163, learning_rate=0.33505224505042003, one_hot_max_size=6, random_strength=1.0005037477317713; total time=  12.5s
# [CV] END bagging_temperature=1.4338876262394629, depth=13, l2_leaf_reg=3.7728291596947163, learning_rate=0.33505224505042003, one_hot_max_size=6, random_strength=1.0005037477317713; total time=  12.4s
# [CV] END bagging_temperature=1.0038378271376383, depth=13, l2_leaf_reg=17.95169417278983, learning_rate=0.330239516465335, one_hot_max_size=2, random_strength=0.3868102936673966; total time=  12.1s
# [CV] END bagging_temperature=1.0038378271376383, depth=13, l2_leaf_reg=17.95169417278983, learning_rate=0.330239516465335, one_hot_max_size=2, random_strength=0.3868102936673966; total time=  11.3s
# [CV] END bagging_temperature=1.0038378271376383, depth=13, l2_leaf_reg=17.95169417278983, learning_rate=0.330239516465335, one_hot_max_size=2, random_strength=0.3868102936673966; total time=  12.4s
# [CV] END bagging_temperature=1.0038378271376383, depth=13, l2_leaf_reg=17.95169417278983, learning_rate=0.330239516465335, one_hot_max_size=2, random_strength=0.3868102936673966; total time=  12.5s
# [CV] END bagging_temperature=1.0038378271376383, depth=13, l2_leaf_reg=17.95169417278983, learning_rate=0.330239516465335, one_hot_max_size=2, random_strength=0.3868102936673966; total time=  12.3s
# [CV] END bagging_temperature=0.20643210660755654, depth=15, l2_leaf_reg=20.544582135766323, learning_rate=0.08889283968359206, one_hot_max_size=5, random_strength=0.01672694755847062; total time=  52.8s
# [CV] END bagging_temperature=0.20643210660755654, depth=15, l2_leaf_reg=20.544582135766323, learning_rate=0.08889283968359206, one_hot_max_size=5, random_strength=0.01672694755847062; total time=  52.9s
# [CV] END bagging_temperature=0.20643210660755654, depth=15, l2_leaf_reg=20.544582135766323, learning_rate=0.08889283968359206, one_hot_max_size=5, random_strength=0.01672694755847062; total time=  52.0s
# [CV] END bagging_temperature=0.20643210660755654, depth=15, l2_leaf_reg=20.544582135766323, learning_rate=0.08889283968359206, one_hot_max_size=5, random_strength=0.01672694755847062; total time=  51.5s
# [CV] END bagging_temperature=0.20643210660755654, depth=15, l2_leaf_reg=20.544582135766323, learning_rate=0.08889283968359206, one_hot_max_size=5, random_strength=0.01672694755847062; total time=  52.2s
# [CV] END bagging_temperature=0.7176305845494884, depth=5, l2_leaf_reg=5.287326919954466, learning_rate=0.03022424750867115, one_hot_max_size=2, random_strength=1.174212527567719; total time=   0.3s
# [CV] END bagging_temperature=0.7176305845494884, depth=5, l2_leaf_reg=5.287326919954466, learning_rate=0.03022424750867115, one_hot_max_size=2, random_strength=1.174212527567719; total time=   0.3s
# [CV] END bagging_temperature=0.7176305845494884, depth=5, l2_leaf_reg=5.287326919954466, learning_rate=0.03022424750867115, one_hot_max_size=2, random_strength=1.174212527567719; total time=   0.3s
# [CV] END bagging_temperature=0.7176305845494884, depth=5, l2_leaf_reg=5.287326919954466, learning_rate=0.03022424750867115, one_hot_max_size=2, random_strength=1.174212527567719; total time=   0.3s
# [CV] END bagging_temperature=0.7176305845494884, depth=5, l2_leaf_reg=5.287326919954466, learning_rate=0.03022424750867115, one_hot_max_size=2, random_strength=1.174212527567719; total time=   0.3s
# [CV] END bagging_temperature=0.4889587009811018, depth=4, l2_leaf_reg=19.183710732352974, learning_rate=0.23521115827707734, one_hot_max_size=2, random_strength=0.12044428503699642; total time=   0.2s
# [CV] END bagging_temperature=0.4889587009811018, depth=4, l2_leaf_reg=19.183710732352974, learning_rate=0.23521115827707734, one_hot_max_size=2, random_strength=0.12044428503699642; total time=   0.2s
# [CV] END bagging_temperature=0.4889587009811018, depth=4, l2_leaf_reg=19.183710732352974, learning_rate=0.23521115827707734, one_hot_max_size=2, random_strength=0.12044428503699642; total time=   0.2s
# [CV] END bagging_temperature=0.4889587009811018, depth=4, l2_leaf_reg=19.183710732352974, learning_rate=0.23521115827707734, one_hot_max_size=2, random_strength=0.12044428503699642; total time=   0.2s
# [CV] END bagging_temperature=0.4889587009811018, depth=4, l2_leaf_reg=19.183710732352974, learning_rate=0.23521115827707734, one_hot_max_size=2, random_strength=0.12044428503699642; total time=   0.2s
# [CV] END bagging_temperature=2.5861903971507236, depth=12, l2_leaf_reg=3.9832737006148893, learning_rate=0.22575254780878293, one_hot_max_size=3, random_strength=4.026779936641323; total time=   6.5s
# [CV] END bagging_temperature=2.5861903971507236, depth=12, l2_leaf_reg=3.9832737006148893, learning_rate=0.22575254780878293, one_hot_max_size=3, random_strength=4.026779936641323; total time=   5.9s
# [CV] END bagging_temperature=2.5861903971507236, depth=12, l2_leaf_reg=3.9832737006148893, learning_rate=0.22575254780878293, one_hot_max_size=3, random_strength=4.026779936641323; total time=   5.7s
# [CV] END bagging_temperature=2.5861903971507236, depth=12, l2_leaf_reg=3.9832737006148893, learning_rate=0.22575254780878293, one_hot_max_size=3, random_strength=4.026779936641323; total time=   6.6s
# [CV] END bagging_temperature=2.5861903971507236, depth=12, l2_leaf_reg=3.9832737006148893, learning_rate=0.22575254780878293, one_hot_max_size=3, random_strength=4.026779936641323; total time=   5.8s
# [CV] END bagging_temperature=0.7269850610302966, depth=3, l2_leaf_reg=3.7687704543790312, learning_rate=0.02954522809498815, one_hot_max_size=5, random_strength=0.8171095395863777; total time=   0.2s
# [CV] END bagging_temperature=0.7269850610302966, depth=3, l2_leaf_reg=3.7687704543790312, learning_rate=0.02954522809498815, one_hot_max_size=5, random_strength=0.8171095395863777; total time=   0.2s
# [CV] END bagging_temperature=0.7269850610302966, depth=3, l2_leaf_reg=3.7687704543790312, learning_rate=0.02954522809498815, one_hot_max_size=5, random_strength=0.8171095395863777; total time=   0.2s
# [CV] END bagging_temperature=0.7269850610302966, depth=3, l2_leaf_reg=3.7687704543790312, learning_rate=0.02954522809498815, one_hot_max_size=5, random_strength=0.8171095395863777; total time=   0.2s
# [CV] END bagging_temperature=0.7269850610302966, depth=3, l2_leaf_reg=3.7687704543790312, learning_rate=0.02954522809498815, one_hot_max_size=5, random_strength=0.8171095395863777; total time=   0.2s
# [CV] END bagging_temperature=2.1424779867144665, depth=9, l2_leaf_reg=5.140465098113239, learning_rate=0.09591352316232879, one_hot_max_size=9, random_strength=1.8751050499355169; total time=   0.9s
# [CV] END bagging_temperature=2.1424779867144665, depth=9, l2_leaf_reg=5.140465098113239, learning_rate=0.09591352316232879, one_hot_max_size=9, random_strength=1.8751050499355169; total time=   1.1s
# [CV] END bagging_temperature=2.1424779867144665, depth=9, l2_leaf_reg=5.140465098113239, learning_rate=0.09591352316232879, one_hot_max_size=9, random_strength=1.8751050499355169; total time=   1.2s
# [CV] END bagging_temperature=2.1424779867144665, depth=9, l2_leaf_reg=5.140465098113239, learning_rate=0.09591352316232879, one_hot_max_size=9, random_strength=1.8751050499355169; total time=   1.1s
# [CV] END bagging_temperature=2.1424779867144665, depth=9, l2_leaf_reg=5.140465098113239, learning_rate=0.09591352316232879, one_hot_max_size=9, random_strength=1.8751050499355169; total time=   0.9s
# [CV] END bagging_temperature=1.940196545963571, depth=8, l2_leaf_reg=16.13562191930903, learning_rate=0.21546213871354103, one_hot_max_size=4, random_strength=2.743185182084907; total time=   0.6s
# [CV] END bagging_temperature=1.940196545963571, depth=8, l2_leaf_reg=16.13562191930903, learning_rate=0.21546213871354103, one_hot_max_size=4, random_strength=2.743185182084907; total time=   0.6s
# [CV] END bagging_temperature=1.940196545963571, depth=8, l2_leaf_reg=16.13562191930903, learning_rate=0.21546213871354103, one_hot_max_size=4, random_strength=2.743185182084907; total time=   0.6s
# [CV] END bagging_temperature=1.940196545963571, depth=8, l2_leaf_reg=16.13562191930903, learning_rate=0.21546213871354103, one_hot_max_size=4, random_strength=2.743185182084907; total time=   0.6s
# [CV] END bagging_temperature=1.940196545963571, depth=8, l2_leaf_reg=16.13562191930903, learning_rate=0.21546213871354103, one_hot_max_size=4, random_strength=2.743185182084907; total time=   0.6s
# [CV] END bagging_temperature=1.5387029311670475, depth=10, l2_leaf_reg=10.324939469655895, learning_rate=0.011847921122198882, one_hot_max_size=7, random_strength=2.815637234575208; total time=   1.8s
# [CV] END bagging_temperature=1.5387029311670475, depth=10, l2_leaf_reg=10.324939469655895, learning_rate=0.011847921122198882, one_hot_max_size=7, random_strength=2.815637234575208; total time=   1.7s
# [CV] END bagging_temperature=1.5387029311670475, depth=10, l2_leaf_reg=10.324939469655895, learning_rate=0.011847921122198882, one_hot_max_size=7, random_strength=2.815637234575208; total time=   1.8s
# [CV] END bagging_temperature=1.5387029311670475, depth=10, l2_leaf_reg=10.324939469655895, learning_rate=0.011847921122198882, one_hot_max_size=7, random_strength=2.815637234575208; total time=   1.7s
# [CV] END bagging_temperature=1.5387029311670475, depth=10, l2_leaf_reg=10.324939469655895, learning_rate=0.011847921122198882, one_hot_max_size=7, random_strength=2.815637234575208; total time=   2.1s
# [CV] END bagging_temperature=3.636812255969223, depth=4, l2_leaf_reg=2.7531581610419904, learning_rate=0.16913956922778636, one_hot_max_size=7, random_strength=0.5949759030314821; total time=   0.3s
# [CV] END bagging_temperature=3.636812255969223, depth=4, l2_leaf_reg=2.7531581610419904, learning_rate=0.16913956922778636, one_hot_max_size=7, random_strength=0.5949759030314821; total time=   0.3s
# [CV] END bagging_temperature=3.636812255969223, depth=4, l2_leaf_reg=2.7531581610419904, learning_rate=0.16913956922778636, one_hot_max_size=7, random_strength=0.5949759030314821; total time=   0.3s
# [CV] END bagging_temperature=3.636812255969223, depth=4, l2_leaf_reg=2.7531581610419904, learning_rate=0.16913956922778636, one_hot_max_size=7, random_strength=0.5949759030314821; total time=   0.3s
# [CV] END bagging_temperature=3.636812255969223, depth=4, l2_leaf_reg=2.7531581610419904, learning_rate=0.16913956922778636, one_hot_max_size=7, random_strength=0.5949759030314821; total time=   0.2s
# [CV] END bagging_temperature=5.195302870591408, depth=6, l2_leaf_reg=13.454172888985388, learning_rate=0.06416475181056118, one_hot_max_size=6, random_strength=0.19701624792324704; total time=   0.3s
# [CV] END bagging_temperature=5.195302870591408, depth=6, l2_leaf_reg=13.454172888985388, learning_rate=0.06416475181056118, one_hot_max_size=6, random_strength=0.19701624792324704; total time=   0.3s
# [CV] END bagging_temperature=5.195302870591408, depth=6, l2_leaf_reg=13.454172888985388, learning_rate=0.06416475181056118, one_hot_max_size=6, random_strength=0.19701624792324704; total time=   0.3s
# [CV] END bagging_temperature=5.195302870591408, depth=6, l2_leaf_reg=13.454172888985388, learning_rate=0.06416475181056118, one_hot_max_size=6, random_strength=0.19701624792324704; total time=   0.4s
# [CV] END bagging_temperature=5.195302870591408, depth=6, l2_leaf_reg=13.454172888985388, learning_rate=0.06416475181056118, one_hot_max_size=6, random_strength=0.19701624792324704; total time=   0.3s
# [CV] END bagging_temperature=0.4564460059011283, depth=10, l2_leaf_reg=19.91956077463401, learning_rate=0.2243626576339525, one_hot_max_size=2, random_strength=0.7820663337722502; total time=   1.8s
# [CV] END bagging_temperature=0.4564460059011283, depth=10, l2_leaf_reg=19.91956077463401, learning_rate=0.2243626576339525, one_hot_max_size=2, random_strength=0.7820663337722502; total time=   1.8s
# [CV] END bagging_temperature=0.4564460059011283, depth=10, l2_leaf_reg=19.91956077463401, learning_rate=0.2243626576339525, one_hot_max_size=2, random_strength=0.7820663337722502; total time=   1.8s
# [CV] END bagging_temperature=0.4564460059011283, depth=10, l2_leaf_reg=19.91956077463401, learning_rate=0.2243626576339525, one_hot_max_size=2, random_strength=0.7820663337722502; total time=   1.8s
# [CV] END bagging_temperature=0.4564460059011283, depth=10, l2_leaf_reg=19.91956077463401, learning_rate=0.2243626576339525, one_hot_max_size=2, random_strength=0.7820663337722502; total time=   1.8s
# [CV] END bagging_temperature=0.7109325606192192, depth=8, l2_leaf_reg=4.081601478588311, learning_rate=0.06594004073248426, one_hot_max_size=7, random_strength=3.8581438253895746; total time=   0.7s
# [CV] END bagging_temperature=0.7109325606192192, depth=8, l2_leaf_reg=4.081601478588311, learning_rate=0.06594004073248426, one_hot_max_size=7, random_strength=3.8581438253895746; total time=   0.7s
# [CV] END bagging_temperature=0.7109325606192192, depth=8, l2_leaf_reg=4.081601478588311, learning_rate=0.06594004073248426, one_hot_max_size=7, random_strength=3.8581438253895746; total time=   0.8s
# [CV] END bagging_temperature=0.7109325606192192, depth=8, l2_leaf_reg=4.081601478588311, learning_rate=0.06594004073248426, one_hot_max_size=7, random_strength=3.8581438253895746; total time=   0.8s
# [CV] END bagging_temperature=0.7109325606192192, depth=8, l2_leaf_reg=4.081601478588311, learning_rate=0.06594004073248426, one_hot_max_size=7, random_strength=3.8581438253895746; total time=   0.6s
# [CV] END bagging_temperature=0.6669769342753803, depth=10, l2_leaf_reg=10.973343857364831, learning_rate=0.32676505053768, one_hot_max_size=7, random_strength=1.035928692551691; total time=   1.8s
# [CV] END bagging_temperature=0.6669769342753803, depth=10, l2_leaf_reg=10.973343857364831, learning_rate=0.32676505053768, one_hot_max_size=7, random_strength=1.035928692551691; total time=   1.8s
# [CV] END bagging_temperature=0.6669769342753803, depth=10, l2_leaf_reg=10.973343857364831, learning_rate=0.32676505053768, one_hot_max_size=7, random_strength=1.035928692551691; total time=   1.8s
# [CV] END bagging_temperature=0.6669769342753803, depth=10, l2_leaf_reg=10.973343857364831, learning_rate=0.32676505053768, one_hot_max_size=7, random_strength=1.035928692551691; total time=   1.8s
# [CV] END bagging_temperature=0.6669769342753803, depth=10, l2_leaf_reg=10.973343857364831, learning_rate=0.32676505053768, one_hot_max_size=7, random_strength=1.035928692551691; total time=   1.9s
# [CV] END bagging_temperature=1.1054075029197246, depth=3, l2_leaf_reg=3.172148953252385, learning_rate=0.26635236061316075, one_hot_max_size=4, random_strength=0.8486418946848798; total time=   0.2s
# [CV] END bagging_temperature=1.1054075029197246, depth=3, l2_leaf_reg=3.172148953252385, learning_rate=0.26635236061316075, one_hot_max_size=4, random_strength=0.8486418946848798; total time=   0.2s
# [CV] END bagging_temperature=1.1054075029197246, depth=3, l2_leaf_reg=3.172148953252385, learning_rate=0.26635236061316075, one_hot_max_size=4, random_strength=0.8486418946848798; total time=   0.2s
# [CV] END bagging_temperature=1.1054075029197246, depth=3, l2_leaf_reg=3.172148953252385, learning_rate=0.26635236061316075, one_hot_max_size=4, random_strength=0.8486418946848798; total time=   0.2s
# [CV] END bagging_temperature=1.1054075029197246, depth=3, l2_leaf_reg=3.172148953252385, learning_rate=0.26635236061316075, one_hot_max_size=4, random_strength=0.8486418946848798; total time=   0.2s
# [CV] END bagging_temperature=1.46340875581733, depth=3, l2_leaf_reg=53.122333989821364, learning_rate=0.13695471746650395, one_hot_max_size=7, random_strength=2.4635098846338415; total time=   0.2s
# [CV] END bagging_temperature=1.46340875581733, depth=3, l2_leaf_reg=53.122333989821364, learning_rate=0.13695471746650395, one_hot_max_size=7, random_strength=2.4635098846338415; total time=   0.2s
# [CV] END bagging_temperature=1.46340875581733, depth=3, l2_leaf_reg=53.122333989821364, learning_rate=0.13695471746650395, one_hot_max_size=7, random_strength=2.4635098846338415; total time=   0.2s
# [CV] END bagging_temperature=1.46340875581733, depth=3, l2_leaf_reg=53.122333989821364, learning_rate=0.13695471746650395, one_hot_max_size=7, random_strength=2.4635098846338415; total time=   0.2s
# [CV] END bagging_temperature=1.46340875581733, depth=3, l2_leaf_reg=53.122333989821364, learning_rate=0.13695471746650395, one_hot_max_size=7, random_strength=2.4635098846338415; total time=   0.2s
# [CV] END bagging_temperature=0.4622873964973667, depth=11, l2_leaf_reg=31.59137506949107, learning_rate=0.09031961036469753, one_hot_max_size=7, random_strength=3.400842016122056; total time=   3.7s
# [CV] END bagging_temperature=0.4622873964973667, depth=11, l2_leaf_reg=31.59137506949107, learning_rate=0.09031961036469753, one_hot_max_size=7, random_strength=3.400842016122056; total time=   3.0s
# [CV] END bagging_temperature=0.4622873964973667, depth=11, l2_leaf_reg=31.59137506949107, learning_rate=0.09031961036469753, one_hot_max_size=7, random_strength=3.400842016122056; total time=   2.9s
# [CV] END bagging_temperature=0.4622873964973667, depth=11, l2_leaf_reg=31.59137506949107, learning_rate=0.09031961036469753, one_hot_max_size=7, random_strength=3.400842016122056; total time=   2.8s
# [CV] END bagging_temperature=0.4622873964973667, depth=11, l2_leaf_reg=31.59137506949107, learning_rate=0.09031961036469753, one_hot_max_size=7, random_strength=3.400842016122056; total time=   3.0s
# [CV] END bagging_temperature=3.3137354761302054, depth=3, l2_leaf_reg=1.783359423664173, learning_rate=0.08296936842253956, one_hot_max_size=9, random_strength=1.9047266524780797; total time=   0.2s
# [CV] END bagging_temperature=3.3137354761302054, depth=3, l2_leaf_reg=1.783359423664173, learning_rate=0.08296936842253956, one_hot_max_size=9, random_strength=1.9047266524780797; total time=   0.2s
# [CV] END bagging_temperature=3.3137354761302054, depth=3, l2_leaf_reg=1.783359423664173, learning_rate=0.08296936842253956, one_hot_max_size=9, random_strength=1.9047266524780797; total time=   0.2s
# [CV] END bagging_temperature=3.3137354761302054, depth=3, l2_leaf_reg=1.783359423664173, learning_rate=0.08296936842253956, one_hot_max_size=9, random_strength=1.9047266524780797; total time=   0.2s
# [CV] END bagging_temperature=3.3137354761302054, depth=3, l2_leaf_reg=1.783359423664173, learning_rate=0.08296936842253956, one_hot_max_size=9, random_strength=1.9047266524780797; total time=   0.2s
# Melhores hiperparâmetros:
# {'bagging_temperature': 1.9713449718798333, 'depth': 9, 'l2_leaf_reg': 2.799114871179353, 'learning_rate': 0.16275231006818694, 'one_hot_max_size': 7, 'random_strength': 0.2511673382758245}
# Melhor MSE: 0.06258197906980631

# %%
{'bagging_temperature': 1.9713449718798333, 'depth': 9, 'l2_leaf_reg': 2.799114871179353, 'learning_rate': 0.16275231006818694, 'one_hot_max_size': 7, 'random_strength': 0.2511673382758245}

# %%
# model
catb_model_tunned = catb.CatBoostRegressor( bagging_temperature= 1.9713449718798333, depth= 9, l2_leaf_reg= 2.799114871179353, learning_rate= 0.16275231006818694, one_hot_max_size= 7, random_strength= 0.2511673382758245, verbose=False).fit( x_train, y_train )

# prediction
yhat_catb_tunned = catb_model_tunned.predict( x_test )

# performance
catb_result_tunned = ml_error( 'CatBoost Regressor', np.expm1( y_test ), np.expm1( yhat_catb_tunned ) )
catb_result_tunned
# Out:
#            Model Name           MAE      MAPE          RMSE
# 0  CatBoost Regressor  26592.553043  0.212671  43093.234506

# %%
cross_validation_regression(catb_model_tunned, x_train, y_train, 5, verbose=True)
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
# {'Model Name': 'CatBoostRegressor',
#  'MAE Mean': 24702.6362,
#  'MAPE Mean': 0.1953,
#  'RMSE Mean': 40299.342}
